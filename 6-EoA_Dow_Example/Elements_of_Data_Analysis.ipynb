# %% [markdown]
# <a name="top" id="top"></a>
#
# <div align="center">
#     <h1>CHE597 - Elements of Data Analysis - </h1>
#     <a href="https://github.com/bernalde">David E. Bernal Neira</a>
#     <br>
#     <i>Davidson School of Chemical Engineering, Purdue University</i>
#     <br>
#     <a href="https://colab.research.google.com/github/SECQUOIA/PU_CHE597_S2025/blob/main/6-EoA_Dow_Example/Elements_of_Data_Analysis.ipynb" target="_parent">
#         <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
#     </a>
#     <a href="https://secquoia.github.io/">
#         <img src="https://img.shields.io/badge/🌲⚛️🌐-SECQUOIA-blue" alt="SECQUOIA"/>
#     </a>
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Elements-of-Data-Analysis" data-toc-modified-id="Elements-of-Data-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Elements of Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Overview-of-the-plant-operation" data-toc-modified-id="Overview-of-the-plant-operation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Overview of the plant operation</a></span></li><li><span><a href="#Summary-of-Variables" data-toc-modified-id="Summary-of-Variables-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Summary of Variables</a></span></li><li><span><a href="#Reading-in-Data" data-toc-modified-id="Reading-in-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Reading in Data</a></span></li><li><span><a href="#Examining-the-contents" data-toc-modified-id="Examining-the-contents-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Examining the contents</a></span></li><li><span><a href="#Correlations" data-toc-modified-id="Correlations-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Correlations</a></span></li></ul></li><li><span><a href="#Removing-Outliers" data-toc-modified-id="Removing-Outliers-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Removing Outliers</a></span><ul class="toc-item"><li><span><a href="#Robust-Z-Score" data-toc-modified-id="Robust-Z-Score-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Robust Z-Score</a></span></li><li><span><a href="#Principal-Component-Analysis-(PCA)" data-toc-modified-id="Principal-Component-Analysis-(PCA)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Principal Component Analysis (PCA)</a></span><ul class="toc-item"><li><span><a href="#Simple-Example" data-toc-modified-id="Simple-Example-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Simple Example</a></span></li><li><span><a href="#Additional-Details-(optional)" data-toc-modified-id="Additional-Details-(optional)-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Additional Details (optional)</a></span></li><li><span><a href="#PCA---Dow-Dataset" data-toc-modified-id="PCA---Dow-Dataset-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>PCA - Dow Dataset</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <b>If you are using google colab you should save this notebook and any associated textfiles to their own folder on your google drive. Then you will need to adapt the following commands so that the notebook runs from the location of that folder.</b>

# %%
# If using this on Google colab, we need to install the packages
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')

    # Colab command to navigate to the folder holding the homework,
    # CHANGE FOR YOUR SPECIFIC FOLDER LOCATION IN GOOGLE DRIVE
    # Note: if there are spaces in the path, you need to preceed them with a backslash '\'
    # %cd /content/drive/My\ Drive/CHE597/Lectures/6-Elements_of_Data_Analysis

# %% [markdown]
# ## Elements of Data Analysis
# In this notebook we will utilize a dataset generously supplied by Dow. This dataset is a time-series comprised of impurity in an output stream and sensor data associated with several unit operations. We'll revisit this dataset as the semester progresses, but here we will utilize it to illustrate basic elements of data analysis, including cleaning data and analyzing basic statistical quantities.
#
# ### Overview of the plant operation
#
# ![dow.png](dow.png)
#
# ### Summary of Variables
# The table below defines the variables for which we have data (huge thanks to Leo Chiang & Dow Chemical Co. for providing data).
# ![dow_variables.png](dow_variables.png)

# %% [markdown]
# ### Reading in Data
# The first thing is to load the data. Dow has made this easy by providing an organized excel spreadsheet (`ImpurityDataset_Training.xlsx`) so we don't need to write our own parser:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dow = pd.read_excel("ImpurityDataset_Training.xlsx")

# %% [markdown]
# In Jupyter, we can view pandas dataframes by just calling the dataframe directly:

# %%
dow
# Out:
#                      Date  x1:Primary Column Reflux Flow  \
# 0     2015-12-01 00:00:00                        327.813
# 1     2015-12-01 01:00:00                        322.970
# 2     2015-12-01 02:00:00                        319.674
# 3     2015-12-01 03:00:00                        327.223
# 4     2015-12-01 04:00:00                        331.177
# ...                   ...                            ...
# 10698 2017-02-18 19:00:00                        397.654
# 10699 2017-02-18 20:00:00                        394.109
# 10700 2017-02-18 21:00:00                        396.095
# 10701 2017-02-18 22:00:00                        392.233
# 10702 2017-02-18 23:00:00                        395.883
#
#        x2:Primary Column Tails Flow  x3:Input to Primary Column Bed 3 Flow  \
# 0                           45.7920                                2095.06
# 1                           46.1643                                2101.00
# 2                           45.9927                                2102.96
# 3                           46.0960                                2101.37
# 4                           45.8493                                2114.06
# ...                             ...                                    ...
# 10698                       48.9312                                2302.54
# 10699                       48.9401                                2290.11
# 10700                       48.8380                                2296.40
# 10701                       49.0474                                2287.61
# 10702                       49.0474                                2302.26
#
#        x4:Input to Primary Column Bed 2 Flow  \
# 0                                    2156.01
# 1                                    2182.90
# 2                                    2151.39
# 3                                    2172.14
# 4                                    2157.77
# ...                                      ...
# 10698                                2405.74
# 10699                                2408.52
# 10700                                2398.71
# 10701                                2394.63
# 10702                                2397.98
#
#        x5:Primary Column Feed Flow from Feed Column  \
# 0                                           98.5005
# 1                                           98.0014
# 2                                           98.8229
# 3                                           98.7733
# 4                                           99.3231
# ...                                             ...
# 10698                                      120.2160
# 10699                                      123.6580
# 10700                                      122.8430
# 10701                                      122.9340
# 10702                                      122.0810
#
#        x6:Primary Column Make Flow  x7:Primary Column Base Level  \
# 0                          95.4674                       54.3476
# 1                          94.9673                       54.2247
# 2                          96.0785                       54.6130
# 3                          96.1223                       54.9153
# 4                          94.7521                       54.0925
# ...                            ...                           ...
# 10698                     116.8420                       53.6651
# 10699                     118.0100                       54.4188
# 10700                     119.7030                       53.9685
# 10701                     119.9190                       54.4196
# 10702                     118.5830                       54.0662
#
#        x8:Primary Column Reflux Drum Pressure  \
# 0                                     41.0121
# 1                                     41.0076
# 2                                     41.0451
# 3                                     41.0405
# 4                                     40.9934
# ...                                       ...
# 10698                                 40.9795
# 10699                                 41.0057
# 10700                                 40.9757
# 10701                                 41.0498
# 10702                                 40.9884
#
#        x9:Primary Column Condenser Reflux Drum Level  ...  \
# 0                                            52.2353  ...
# 1                                            52.5378  ...
# 2                                            52.0159  ...
# 3                                            52.9477  ...
# 4                                            53.0507  ...
# ...                                              ...  ...
# 10698                                        53.3360  ...
# 10699                                        52.7054  ...
# 10700                                        53.1350  ...
# 10701                                        52.7341  ...
# 10702                                        53.2160  ...
#
#        x36: Feed Column Recycle Flow  \
# 0                            62.8707
# 1                            62.8651
# 2                            62.8656
# 3                            62.8669
# 4                            62.8673
# ...                              ...
# 10698                        62.9370
# 10699                        62.9370
# 10700                        62.9404
# 10701                        62.9370
# 10702                        62.9388
#
#        x37: Feed Column Tails Flow to Primary Column  \
# 0                                            45.0085
# 1                                            45.0085
# 2                                            45.0085
# 3                                            45.0085
# 4                                            45.0085
# ...                                              ...
# 10698                                        45.0085
# 10699                                        45.0085
# 10700                                        45.0085
# 10701                                        45.0085
# 10702                                        45.0085
#
#        x38: Feed Column Calculated DP  x39: Feed Column Steam Flow  \
# 0                             66.6604                      8.68813
# 1                             66.5496                      8.70683
# 2                             66.0599                      8.69269
# 3                             67.9697                      8.70482
# 4                             67.6454                      8.70077
# ...                               ...                          ...
# 10698                         71.3254                      8.99703
# 10699                         73.9447                      9.00320
# 10700                         71.8156                      9.00187
# 10701                         72.0492                      9.00924
# 10702                         70.2841                      9.00932
#
#        x40: Feed Column Tails Flow  Avg_Reactor_Outlet_Impurity  \
# 0                          99.9614                      5.38024
# 1                          99.8637                      5.33345
# 2                         100.2490                      5.37677
# 3                         100.3200                      5.32315
# 4                         100.6590                      5.28227
# ...                            ...                          ...
# 10698                     121.7330                     10.09520
# 10699                     124.9870                      9.51403
# 10700                     124.2270                     10.03550
# 10701                     124.4240                      9.95938
# 10702                     123.5760                      9.90099
#
#        Avg_Delta_Composition Primary Column  y:Impurity  \
# 0                                   1.49709     1.77833
# 1                                   1.51392     1.76964
# 2                                   1.50634     1.76095
# 3                                   1.47935     1.75226
# 4                                   1.44489     1.74357
# ...                                     ...         ...
# 10698                               2.15861     3.12650
# 10699                               2.21241     3.10883
# 10700                               2.17251     3.07895
# 10701                               2.15922     3.03684
# 10702                               2.13766     2.99474
#
#        Primary Column Reflux/Feed Ratio  Primary Column Make/Reflux Ratio
# 0                               3.32803                          0.291226
# 1                               3.29556                          0.294044
# 2                               3.23481                          0.300552
# 3                               3.31287                          0.293752
# 4                               3.33435                          0.286107
# ...                                 ...                               ...
# 10698                           3.30783                          0.293829
# 10699                           3.18708                          0.299435
# 10700                           3.22441                          0.302209
# 10701                           3.19061                          0.305736
# 10702                           3.24280                          0.299539
#
# [10703 rows x 46 columns]

# %% [markdown]
# ### Examining the contents
# We have a large block of data, but what exactly is it? We need to figure out what our headers are, how many missing values we have, and what our relevant output quantities are.
#
# First, let's just summarize the headers:

# %%
# Check the columns and datatypes
for i in dow.columns:
    print("{}: {}".format(i,dow[i].dtype))
# Out:
# Date: datetime64[ns]
# x1:Primary Column Reflux Flow: float64
# x2:Primary Column Tails Flow: float64
# x3:Input to Primary Column Bed 3 Flow: float64
# x4:Input to Primary Column Bed 2 Flow: float64
# x5:Primary Column Feed Flow from Feed Column: float64
# x6:Primary Column Make Flow: float64
# x7:Primary Column Base Level: float64
# x8:Primary Column Reflux Drum Pressure: float64
# x9:Primary Column Condenser Reflux Drum Level: float64
# x10:Primary Column Bed1 DP: float64
# x11:Primary Column Bed2 DP: float64
# x12:Primary Column Bed3 DP: float64
# x13:Primary Column Bed4 DP: float64
# x14:Primary Column Base Pressure: float64
# x15:Primary Column Head Pressure: float64
# x16:Primary Column Tails Temperature: float64
# x17:Primary Column Tails Temperature 1: float64
# x18:Primary Column Bed 4 Temperature: float64
# x19:Primary Column Bed 3 Temperature: float64
# x20:Primary Column Bed 2 Temperature: float64
# x21:Primary Column Bed 1 Temperature: float64
# x22: Secondary Column Base Concentration: float64
# x23: Flow from Input to Secondary Column: float64
# x24: Secondary Column Tails Flow: float64
# x25: Secondary Column Tray DP: float64
# x26: Secondary Column Head Pressure: float64
# x27: Secondary Column Base Pressure: float64
# x28: Secondary Column Base Temperature: float64
# x29: Secondary Column Tray 3 Temperature: float64
# x30: Secondary Column Bed 1 Temperature: float64
# x31: Secondary Column Bed 2 Temperature: float64
# x32: Secondary Column Tray 2 Temperature: float64
# x33: Secondary Column Tray 1 Temperature: float64
# x34: Secondary Column Tails Temperature: float64
# x35: Secondary Column Tails Concentration: float64
# x36: Feed Column Recycle Flow: float64
# x37: Feed Column Tails Flow to Primary Column: object
# x38: Feed Column Calculated DP: float64
# x39: Feed Column Steam Flow: float64
# x40: Feed Column Tails Flow: float64
# Avg_Reactor_Outlet_Impurity: float64
# Avg_Delta_Composition Primary Column: float64
# y:Impurity: float64
# Primary Column Reflux/Feed Ratio: float64
# Primary Column Make/Reflux Ratio: float64

# %% [markdown]
# There are lots of variables here. Based on the description, the `xINT:` variables correspond to sensor readings and the `y:Impurity` variable is the process figure of merit that we are intent on predicting. Let's take a look at `y:Impurity` vs time to get a sense of the problem:

# %%
plt.figure(figsize=(12,3))
plt.plot(dow.iloc[:,0],dow.iloc[:,-3],marker='o')
plt.xlabel("time")
plt.ylabel("y:Impurity")
plt.show()

# %% [markdown]
# Here we can see potential issues with outliers. We can also see some strange behavior near the end, where the noise (which we expect) seems to go away and the impurity drifts linearly. Let's take a closer look:

# %%
plt.figure(figsize=(12,3))
plt.plot(dow.iloc[-1000:,0],dow.iloc[-1000:,-3],marker='o')
plt.xlabel("time")
plt.ylabel("y:Impurity")
plt.show()

# %% [markdown]
# Something is clearly odd here. In fact, our friends at dow have told us that some of the units were shutdown during the period that these readings were taken, and identifying these periods is one of the challenges we'll discuss with this dataset in the next lecture.
#
# A second generic consideration with any dataset is identifying missing values. Let's write a pandas operation to identify how many missing values we have in every column:

# %%
# Loop over columns and use .isna() and .sum() methods to identify NaN and sum their quantity, respectively
N = len(dow)
for i in dow.columns:
    N_missing = dow[i].isna().sum()
    print("{}: {} ({:4.2f}%)".format(i,N_missing,N_missing/N*100.0))
# Out:
# Date: 0 (0.00%)
# x1:Primary Column Reflux Flow: 30 (0.28%)
# x2:Primary Column Tails Flow: 22 (0.21%)
# x3:Input to Primary Column Bed 3 Flow: 21 (0.20%)
# x4:Input to Primary Column Bed 2 Flow: 21 (0.20%)
# x5:Primary Column Feed Flow from Feed Column: 21 (0.20%)
# x6:Primary Column Make Flow: 21 (0.20%)
# x7:Primary Column Base Level: 21 (0.20%)
# x8:Primary Column Reflux Drum Pressure: 21 (0.20%)
# x9:Primary Column Condenser Reflux Drum Level: 19 (0.18%)
# x10:Primary Column Bed1 DP: 19 (0.18%)
# x11:Primary Column Bed2 DP: 19 (0.18%)
# x12:Primary Column Bed3 DP: 19 (0.18%)
# x13:Primary Column Bed4 DP: 20 (0.19%)
# x14:Primary Column Base Pressure: 19 (0.18%)
# x15:Primary Column Head Pressure: 21 (0.20%)
# x16:Primary Column Tails Temperature: 19 (0.18%)
# x17:Primary Column Tails Temperature 1: 19 (0.18%)
# x18:Primary Column Bed 4 Temperature: 19 (0.18%)
# x19:Primary Column Bed 3 Temperature: 19 (0.18%)
# x20:Primary Column Bed 2 Temperature: 19 (0.18%)
# x21:Primary Column Bed 1 Temperature: 19 (0.18%)
# x22: Secondary Column Base Concentration: 19 (0.18%)
# x23: Flow from Input to Secondary Column: 23 (0.21%)
# x24: Secondary Column Tails Flow: 21 (0.20%)
# x25: Secondary Column Tray DP: 19 (0.18%)
# x26: Secondary Column Head Pressure: 19 (0.18%)
# x27: Secondary Column Base Pressure: 20 (0.19%)
# x28: Secondary Column Base Temperature: 19 (0.18%)
# x29: Secondary Column Tray 3 Temperature: 20 (0.19%)
# x30: Secondary Column Bed 1 Temperature: 19 (0.18%)
# x31: Secondary Column Bed 2 Temperature: 19 (0.18%)
# x32: Secondary Column Tray 2 Temperature: 19 (0.18%)
# x33: Secondary Column Tray 1 Temperature: 19 (0.18%)
# x34: Secondary Column Tails Temperature: 21 (0.20%)
# x35: Secondary Column Tails Concentration: 19 (0.18%)
# x36: Feed Column Recycle Flow: 19 (0.18%)
# x37: Feed Column Tails Flow to Primary Column: 17 (0.16%)
# x38: Feed Column Calculated DP: 21 (0.20%)
# x39: Feed Column Steam Flow: 19 (0.18%)
# x40: Feed Column Tails Flow: 21 (0.20%)
# Avg_Reactor_Outlet_Impurity: 97 (0.91%)
# Avg_Delta_Composition Primary Column: 291 (2.72%)
# y:Impurity: 0 (0.00%)
# Primary Column Reflux/Feed Ratio: 30 (0.28%)
# Primary Column Make/Reflux Ratio: 30 (0.28%)

# %% [markdown]
# We have missing values, but in all cases it is only a fraction of a percent of the total data. Since it is such a small amount, let's remove all rows with missing data:

# %%
# Drop rows with any missing data
dow.dropna(how='any',inplace=True)

# Check that we successfully removed the missing values
print("number of missing values: {}".format(dow.isna().sum().sum()))
# Out:
# number of missing values: 0

# %% [markdown]
# Here we have checked that we successfully removed the missing values by recomputing the missing values with `.isna()` and doing a double summation.
#
# If you looked closely when you calculated the headers and datatypes, then you would also see that `x37:` has some missing values assigned as strings. We can also remove non-numeric values using the following bit of code:

# %%
cols=["x37: Feed Column Tails Flow to Primary Column"]# columns we want to remove non-numeric data from

# error='coerce' will return NaN if can't be converted to numeric.
dow[cols] = dow[cols].apply(pd.to_numeric,errors='coerce')

# drop rows with missing values 
dow.dropna(how='any',inplace=True)

# Check that we successfully removed the missing values
print("number of missing values: {}".format(dow.isna().sum().sum()))
# Out:
# number of missing values: 0

# %% [markdown]
# Let's replot the impurity and see if the trends have qualitatively changed:

# %%
# Check the impurity plot    
plt.figure(figsize=(12,3))
plt.plot(dow.iloc[:,0],dow.iloc[:,-3],marker='o')
plt.xlabel("time")
plt.ylabel("y:Impurity")
plt.show()

# %% [markdown]
# Comparing the resulting impurity plot with the original, we can see that it is largely unchanged. If you look closely you can see a gap in april-2016 and some other missing points. Our eventual goal with this dataset will be to predict the impurity based on the sensor readings. In the current case, even with the removed values we still have plenty of data for training such a model (this might not always be the case, and sometimes missing values are themselves a useful predictor for modeling).

# %% [markdown]
# ### Correlations
# We have a lot of sensor readings related to the unit operations (40 of them). Absent other knowledge, we don't know if these are all important, if none of them are important, or if we actually need even more variables to construct a useful model.
#
# When you have a lot of variables, a simple and informative thing to calculate is the linear correlation coefficient:
#
# $r_{xy} = \frac{\sum_{i}\left(x_i - \mu_x\right)\left(y_i - \mu_y\right)}{\sqrt{\sum_i \left(x_i - \mu_x\right)^2}\sqrt{\sum_i \left(y_i - \mu_y\right)^2}}$
#
# Where $x_i$ and $y_i$ are the values of properties $X$ and $Y$ at a given time $i$, and $\mu_x$ and $\mu_y$ are the average values of $X$ and $Y$ over the dataset. This quantity (which you have probably seen before, but if not you should certainly internalize), is bounded between -1 and 1, and tells us if the two variables $X$ and $Y$ tend to move together. Specifically, the numerator holds the sum of products between $x_i$ fluctations from its mean and $y_i$ fluctuations from its mean. If these fluctuations happen in the same direction the coefficient will tend toward 1, if they typically happen in opposite directions the coefficient will tend towards -1, and if they don't move together in a linear fashion then it will tend towards 0. Since $X$ and $Y$ have potentially different units and variance, the denominator normalizes these fluctations by each variable's standard deviation.
#
# We care about correlation, because it is simplest opportunity for finding important variables for predicting our property of interest. In this course, we will typically focus on problems where linear regression doesn't work, but if you happen to have good linear predictor variables, that is wonderful and you should identify this right away.
#
# Thankfully, Pandas has a built-in method for calculating the correlation between columns:

# %%
corr = dow.corr()
corr
# Out:
#                                                    Date  \
# Date                                           1.000000
# x1:Primary Column Reflux Flow                 -0.266811
# x2:Primary Column Tails Flow                  -0.268958
# x3:Input to Primary Column Bed 3 Flow          0.140706
# x4:Input to Primary Column Bed 2 Flow         -0.259891
# x5:Primary Column Feed Flow from Feed Column  -0.296091
# x6:Primary Column Make Flow                   -0.288894
# x7:Primary Column Base Level                  -0.242609
# x8:Primary Column Reflux Drum Pressure        -0.332783
# x9:Primary Column Condenser Reflux Drum Level -0.301012
# x10:Primary Column Bed1 DP                    -0.117920
# x11:Primary Column Bed2 DP                    -0.191753
# x12:Primary Column Bed3 DP                    -0.209625
# x13:Primary Column Bed4 DP                    -0.405053
# x14:Primary Column Base Pressure              -0.336328
# x15:Primary Column Head Pressure              -0.334759
# x16:Primary Column Tails Temperature           0.016979
# x17:Primary Column Tails Temperature 1        -0.132014
# x18:Primary Column Bed 4 Temperature          -0.352571
# x19:Primary Column Bed 3 Temperature          -0.351235
# x20:Primary Column Bed 2 Temperature          -0.337776
# x21:Primary Column Bed 1 Temperature          -0.319734
# x22: Secondary Column Base Concentration       0.254936
# x23: Flow from Input to Secondary Column      -0.568111
# x24: Secondary Column Tails Flow              -0.143976
# x25: Secondary Column Tray DP                 -0.360623
# x26: Secondary Column Head Pressure           -0.332731
# x27: Secondary Column Base Pressure           -0.336715
# x28: Secondary Column Base Temperature        -0.305421
# x29: Secondary Column Tray 3 Temperature      -0.182656
# x30: Secondary Column Bed 1 Temperature       -0.216853
# x31: Secondary Column Bed 2 Temperature       -0.245070
# x32: Secondary Column Tray 2 Temperature      -0.010698
# x33: Secondary Column Tray 1 Temperature      -0.301623
# x34: Secondary Column Tails Temperature       -0.286950
# x35: Secondary Column Tails Concentration      0.045268
# x36: Feed Column Recycle Flow                 -0.297909
# x37: Feed Column Tails Flow to Primary Column -0.101549
# x38: Feed Column Calculated DP                -0.187006
# x39: Feed Column Steam Flow                   -0.326604
# x40: Feed Column Tails Flow                   -0.298492
# Avg_Reactor_Outlet_Impurity                    0.250210
# Avg_Delta_Composition Primary Column          -0.132035
# y:Impurity                                     0.011287
# Primary Column Reflux/Feed Ratio               0.018953
# Primary Column Make/Reflux Ratio              -0.026926
#
#                                                x1:Primary Column Reflux Flow  \
# Date                                                               -0.266811
# x1:Primary Column Reflux Flow                                       1.000000
# x2:Primary Column Tails Flow                                        0.840909
# x3:Input to Primary Column Bed 3 Flow                               0.638107
# x4:Input to Primary Column Bed 2 Flow                               0.790147
# x5:Primary Column Feed Flow from Feed Column                        0.915221
# x6:Primary Column Make Flow                                         0.869800
# x7:Primary Column Base Level                                        0.733663
# x8:Primary Column Reflux Drum Pressure                              0.565074
# x9:Primary Column Condenser Reflux Drum Level                       0.788199
# x10:Primary Column Bed1 DP                                          0.797622
# x11:Primary Column Bed2 DP                                          0.847849
# x12:Primary Column Bed3 DP                                          0.826132
# x13:Primary Column Bed4 DP                                          0.765703
# x14:Primary Column Base Pressure                                    0.671810
# x15:Primary Column Head Pressure                                    0.597378
# x16:Primary Column Tails Temperature                                0.191140
# x17:Primary Column Tails Temperature 1                              0.114839
# x18:Primary Column Bed 4 Temperature                                0.812402
# x19:Primary Column Bed 3 Temperature                                0.811803
# x20:Primary Column Bed 2 Temperature                                0.800865
# x21:Primary Column Bed 1 Temperature                                0.792902
# x22: Secondary Column Base Concentration                           -0.767616
# x23: Flow from Input to Secondary Column                            0.416200
# x24: Secondary Column Tails Flow                                    0.696532
# x25: Secondary Column Tray DP                                       0.673110
# x26: Secondary Column Head Pressure                                 0.681969
# x27: Secondary Column Base Pressure                                 0.692741
# x28: Secondary Column Base Temperature                              0.697901
# x29: Secondary Column Tray 3 Temperature                            0.367563
# x30: Secondary Column Bed 1 Temperature                             0.486803
# x31: Secondary Column Bed 2 Temperature                             0.573291
# x32: Secondary Column Tray 2 Temperature                            0.232276
# x33: Secondary Column Tray 1 Temperature                            0.355501
# x34: Secondary Column Tails Temperature                             0.806784
# x35: Secondary Column Tails Concentration                          -0.156692
# x36: Feed Column Recycle Flow                                       0.689768
# x37: Feed Column Tails Flow to Primary Column                       0.470948
# x38: Feed Column Calculated DP                                      0.613797
# x39: Feed Column Steam Flow                                         0.762032
# x40: Feed Column Tails Flow                                         0.909378
# Avg_Reactor_Outlet_Impurity                                         0.706999
# Avg_Delta_Composition Primary Column                                0.852385
# y:Impurity                                                          0.529820
# Primary Column Reflux/Feed Ratio                                    0.008352
# Primary Column Make/Reflux Ratio                                    0.049966
#
#                                                x2:Primary Column Tails Flow  \
# Date                                                              -0.268958
# x1:Primary Column Reflux Flow                                      0.840909
# x2:Primary Column Tails Flow                                       1.000000
# x3:Input to Primary Column Bed 3 Flow                              0.755112
# x4:Input to Primary Column Bed 2 Flow                              0.879539
# x5:Primary Column Feed Flow from Feed Column                       0.739763
# x6:Primary Column Make Flow                                        0.698189
# x7:Primary Column Base Level                                       0.845652
# x8:Primary Column Reflux Drum Pressure                             0.622606
# x9:Primary Column Condenser Reflux Drum Level                      0.884212
# x10:Primary Column Bed1 DP                                         0.454977
# x11:Primary Column Bed2 DP                                         0.484717
# x12:Primary Column Bed3 DP                                         0.463684
# x13:Primary Column Bed4 DP                                         0.490729
# x14:Primary Column Base Pressure                                   0.666064
# x15:Primary Column Head Pressure                                   0.639539
# x16:Primary Column Tails Temperature                               0.178789
# x17:Primary Column Tails Temperature 1                             0.204466
# x18:Primary Column Bed 4 Temperature                               0.918714
# x19:Primary Column Bed 3 Temperature                               0.914971
# x20:Primary Column Bed 2 Temperature                               0.898447
# x21:Primary Column Bed 1 Temperature                               0.872657
# x22: Secondary Column Base Concentration                          -0.923351
# x23: Flow from Input to Secondary Column                           0.501162
# x24: Secondary Column Tails Flow                                   0.737931
# x25: Secondary Column Tray DP                                      0.862831
# x26: Secondary Column Head Pressure                                0.676006
# x27: Secondary Column Base Pressure                                0.694561
# x28: Secondary Column Base Temperature                             0.840182
# x29: Secondary Column Tray 3 Temperature                           0.483122
# x30: Secondary Column Bed 1 Temperature                            0.559752
# x31: Secondary Column Bed 2 Temperature                            0.619534
# x32: Secondary Column Tray 2 Temperature                           0.417170
# x33: Secondary Column Tray 1 Temperature                           0.631591
# x34: Secondary Column Tails Temperature                            0.952371
# x35: Secondary Column Tails Concentration                         -0.212880
# x36: Feed Column Recycle Flow                                      0.754131
# x37: Feed Column Tails Flow to Primary Column                      0.540855
# x38: Feed Column Calculated DP                                     0.668350
# x39: Feed Column Steam Flow                                        0.814919
# x40: Feed Column Tails Flow                                        0.745062
# Avg_Reactor_Outlet_Impurity                                        0.517891
# Avg_Delta_Composition Primary Column                               0.664198
# y:Impurity                                                         0.277642
# Primary Column Reflux/Feed Ratio                                   0.004357
# Primary Column Make/Reflux Ratio                                   0.040210
#
#                                                x3:Input to Primary Column Bed 3 Flow  \
# Date                                                                        0.140706
# x1:Primary Column Reflux Flow                                               0.638107
# x2:Primary Column Tails Flow                                                0.755112
# x3:Input to Primary Column Bed 3 Flow                                       1.000000
# x4:Input to Primary Column Bed 2 Flow                                       0.703178
# x5:Primary Column Feed Flow from Feed Column                                0.621706
# x6:Primary Column Make Flow                                                 0.611063
# x7:Primary Column Base Level                                                0.657509
# x8:Primary Column Reflux Drum Pressure                                      0.319365
# x9:Primary Column Condenser Reflux Drum Level                               0.687136
# x10:Primary Column Bed1 DP                                                  0.441262
# x11:Primary Column Bed2 DP                                                  0.381931
# x12:Primary Column Bed3 DP                                                  0.305299
# x13:Primary Column Bed4 DP                                                  0.414173
# x14:Primary Column Base Pressure                                            0.370620
# x15:Primary Column Head Pressure                                            0.338551
# x16:Primary Column Tails Temperature                                        0.194705
# x17:Primary Column Tails Temperature 1                                      0.123300
# x18:Primary Column Bed 4 Temperature                                        0.611556
# x19:Primary Column Bed 3 Temperature                                        0.611091
# x20:Primary Column Bed 2 Temperature                                        0.606105
# x21:Primary Column Bed 1 Temperature                                        0.605494
# x22: Secondary Column Base Concentration                                   -0.708674
# x23: Flow from Input to Secondary Column                                    0.013550
# x24: Secondary Column Tails Flow                                            0.719940
# x25: Secondary Column Tray DP                                               0.615637
# x26: Secondary Column Head Pressure                                         0.385194
# x27: Secondary Column Base Pressure                                         0.399839
# x28: Secondary Column Base Temperature                                      0.600435
# x29: Secondary Column Tray 3 Temperature                                    0.351988
# x30: Secondary Column Bed 1 Temperature                                     0.388845
# x31: Secondary Column Bed 2 Temperature                                     0.433455
# x32: Secondary Column Tray 2 Temperature                                    0.305980
# x33: Secondary Column Tray 1 Temperature                                    0.478330
# x34: Secondary Column Tails Temperature                                     0.702396
# x35: Secondary Column Tails Concentration                                  -0.158079
# x36: Feed Column Recycle Flow                                               0.619985
# x37: Feed Column Tails Flow to Primary Column                               0.535161
# x38: Feed Column Calculated DP                                              0.581383
# x39: Feed Column Steam Flow                                                 0.681222
# x40: Feed Column Tails Flow                                                 0.621492
# Avg_Reactor_Outlet_Impurity                                                 0.691601
# Avg_Delta_Composition Primary Column                                        0.638122
# y:Impurity                                                                  0.328518
# Primary Column Reflux/Feed Ratio                                           -0.030249
# Primary Column Make/Reflux Ratio                                            0.053109
#
#                                                x4:Input to Primary Column Bed 2 Flow  \
# Date                                                                       -0.259891
# x1:Primary Column Reflux Flow                                               0.790147
# x2:Primary Column Tails Flow                                                0.879539
# x3:Input to Primary Column Bed 3 Flow                                       0.703178
# x4:Input to Primary Column Bed 2 Flow                                       1.000000
# x5:Primary Column Feed Flow from Feed Column                                0.732774
# x6:Primary Column Make Flow                                                 0.702620
# x7:Primary Column Base Level                                                0.726438
# x8:Primary Column Reflux Drum Pressure                                      0.560686
# x9:Primary Column Condenser Reflux Drum Level                               0.780996
# x10:Primary Column Bed1 DP                                                  0.525478
# x11:Primary Column Bed2 DP                                                  0.499420
# x12:Primary Column Bed3 DP                                                  0.457988
# x13:Primary Column Bed4 DP                                                  0.546160
# x14:Primary Column Base Pressure                                            0.612646
# x15:Primary Column Head Pressure                                            0.579058
# x16:Primary Column Tails Temperature                                        0.239697
# x17:Primary Column Tails Temperature 1                                      0.195191
# x18:Primary Column Bed 4 Temperature                                        0.808679
# x19:Primary Column Bed 3 Temperature                                        0.803835
# x20:Primary Column Bed 2 Temperature                                        0.789610
# x21:Primary Column Bed 1 Temperature                                        0.781421
# x22: Secondary Column Base Concentration                                   -0.785537
# x23: Flow from Input to Secondary Column                                    0.585410
# x24: Secondary Column Tails Flow                                            0.818751
# x25: Secondary Column Tray DP                                               0.697407
# x26: Secondary Column Head Pressure                                         0.624958
# x27: Secondary Column Base Pressure                                         0.637090
# x28: Secondary Column Base Temperature                                      0.717379
# x29: Secondary Column Tray 3 Temperature                                    0.364837
# x30: Secondary Column Bed 1 Temperature                                     0.438633
# x31: Secondary Column Bed 2 Temperature                                     0.544378
# x32: Secondary Column Tray 2 Temperature                                    0.345874
# x33: Secondary Column Tray 1 Temperature                                    0.536506
# x34: Secondary Column Tails Temperature                                     0.821521
# x35: Secondary Column Tails Concentration                                  -0.175041
# x36: Feed Column Recycle Flow                                               0.645427
# x37: Feed Column Tails Flow to Primary Column                               0.569785
# x38: Feed Column Calculated DP                                              0.595774
# x39: Feed Column Steam Flow                                                 0.751539
# x40: Feed Column Tails Flow                                                 0.739285
# Avg_Reactor_Outlet_Impurity                                                 0.505818
# Avg_Delta_Composition Primary Column                                        0.678863
# y:Impurity                                                                  0.383029
# Primary Column Reflux/Feed Ratio                                           -0.047659
# Primary Column Make/Reflux Ratio                                            0.047871
#
#                                                x5:Primary Column Feed Flow from Feed Column  \
# Date                                                                              -0.296091
# x1:Primary Column Reflux Flow                                                      0.915221
# x2:Primary Column Tails Flow                                                       0.739763
# x3:Input to Primary Column Bed 3 Flow                                              0.621706
# x4:Input to Primary Column Bed 2 Flow                                              0.732774
# x5:Primary Column Feed Flow from Feed Column                                       1.000000
# x6:Primary Column Make Flow                                                        0.949683
# x7:Primary Column Base Level                                                       0.662324
# x8:Primary Column Reflux Drum Pressure                                             0.461143
# x9:Primary Column Condenser Reflux Drum Level                                      0.722785
# x10:Primary Column Bed1 DP                                                         0.804096
# x11:Primary Column Bed2 DP                                                         0.828010
# x12:Primary Column Bed3 DP                                                         0.788415
# x13:Primary Column Bed4 DP                                                         0.802565
# x14:Primary Column Base Pressure                                                   0.573457
# x15:Primary Column Head Pressure                                                   0.495548
# x16:Primary Column Tails Temperature                                               0.216999
# x17:Primary Column Tails Temperature 1                                             0.074125
# x18:Primary Column Bed 4 Temperature                                               0.685917
# x19:Primary Column Bed 3 Temperature                                               0.687110
# x20:Primary Column Bed 2 Temperature                                               0.683273
# x21:Primary Column Bed 1 Temperature                                               0.684498
# x22: Secondary Column Base Concentration                                          -0.660182
# x23: Flow from Input to Secondary Column                                           0.333086
# x24: Secondary Column Tails Flow                                                   0.725111
# x25: Secondary Column Tray DP                                                      0.596459
# x26: Secondary Column Head Pressure                                                0.585563
# x27: Secondary Column Base Pressure                                                0.593809
# x28: Secondary Column Base Temperature                                             0.601766
# x29: Secondary Column Tray 3 Temperature                                           0.328214
# x30: Secondary Column Bed 1 Temperature                                            0.424873
# x31: Secondary Column Bed 2 Temperature                                            0.502416
# x32: Secondary Column Tray 2 Temperature                                           0.126569
# x33: Secondary Column Tray 1 Temperature                                           0.353449
# x34: Secondary Column Tails Temperature                                            0.694556
# x35: Secondary Column Tails Concentration                                         -0.129778
# x36: Feed Column Recycle Flow                                                      0.777537
# x37: Feed Column Tails Flow to Primary Column                                      0.555507
# x38: Feed Column Calculated DP                                                     0.730696
# x39: Feed Column Steam Flow                                                        0.858223
# x40: Feed Column Tails Flow                                                        0.993502
# Avg_Reactor_Outlet_Impurity                                                        0.774289
# Avg_Delta_Composition Primary Column                                               0.930925
# y:Impurity                                                                         0.592390
# Primary Column Reflux/Feed Ratio                                                  -0.054194
# Primary Column Make/Reflux Ratio                                                   0.082852
#
#                                                x6:Primary Column Make Flow  \
# Date                                                             -0.288894
# x1:Primary Column Reflux Flow                                     0.869800
# x2:Primary Column Tails Flow                                      0.698189
# x3:Input to Primary Column Bed 3 Flow                             0.611063
# x4:Input to Primary Column Bed 2 Flow                             0.702620
# x5:Primary Column Feed Flow from Feed Column                      0.949683
# x6:Primary Column Make Flow                                       1.000000
# x7:Primary Column Base Level                                      0.616827
# x8:Primary Column Reflux Drum Pressure                            0.408036
# x9:Primary Column Condenser Reflux Drum Level                     0.665838
# x10:Primary Column Bed1 DP                                        0.758701
# x11:Primary Column Bed2 DP                                        0.802774
# x12:Primary Column Bed3 DP                                        0.778134
# x13:Primary Column Bed4 DP                                        0.802294
# x14:Primary Column Base Pressure                                  0.520019
# x15:Primary Column Head Pressure                                  0.442333
# x16:Primary Column Tails Temperature                              0.211920
# x17:Primary Column Tails Temperature 1                            0.053370
# x18:Primary Column Bed 4 Temperature                              0.618465
# x19:Primary Column Bed 3 Temperature                              0.620624
# x20:Primary Column Bed 2 Temperature                              0.618343
# x21:Primary Column Bed 1 Temperature                              0.617734
# x22: Secondary Column Base Concentration                         -0.599693
# x23: Flow from Input to Secondary Column                          0.305176
# x24: Secondary Column Tails Flow                                  0.671190
# x25: Secondary Column Tray DP                                     0.572720
# x26: Secondary Column Head Pressure                               0.532777
# x27: Secondary Column Base Pressure                               0.541463
# x28: Secondary Column Base Temperature                            0.545404
# x29: Secondary Column Tray 3 Temperature                          0.283830
# x30: Secondary Column Bed 1 Temperature                           0.362277
# x31: Secondary Column Bed 2 Temperature                           0.431476
# x32: Secondary Column Tray 2 Temperature                          0.071678
# x33: Secondary Column Tray 1 Temperature                          0.298920
# x34: Secondary Column Tails Temperature                           0.631962
# x35: Secondary Column Tails Concentration                        -0.124351
# x36: Feed Column Recycle Flow                                     0.703651
# x37: Feed Column Tails Flow to Primary Column                     0.507520
# x38: Feed Column Calculated DP                                    0.683486
# x39: Feed Column Steam Flow                                       0.804732
# x40: Feed Column Tails Flow                                       0.935731
# Avg_Reactor_Outlet_Impurity                                       0.815685
# Avg_Delta_Composition Primary Column                              0.977973
# y:Impurity                                                        0.580705
# Primary Column Reflux/Feed Ratio                                 -0.050222
# Primary Column Make/Reflux Ratio                                  0.100181
#
#                                                x7:Primary Column Base Level  \
# Date                                                              -0.242609
# x1:Primary Column Reflux Flow                                      0.733663
# x2:Primary Column Tails Flow                                       0.845652
# x3:Input to Primary Column Bed 3 Flow                              0.657509
# x4:Input to Primary Column Bed 2 Flow                              0.726438
# x5:Primary Column Feed Flow from Feed Column                       0.662324
# x6:Primary Column Make Flow                                        0.616827
# x7:Primary Column Base Level                                       1.000000
# x8:Primary Column Reflux Drum Pressure                             0.652882
# x9:Primary Column Condenser Reflux Drum Level                      0.893422
# x10:Primary Column Bed1 DP                                         0.438674
# x11:Primary Column Bed2 DP                                         0.455355
# x12:Primary Column Bed3 DP                                         0.424944
# x13:Primary Column Bed4 DP                                         0.442175
# x14:Primary Column Base Pressure                                   0.687227
# x15:Primary Column Head Pressure                                   0.666353
# x16:Primary Column Tails Temperature                               0.166460
# x17:Primary Column Tails Temperature 1                             0.180125
# x18:Primary Column Bed 4 Temperature                               0.886001
# x19:Primary Column Bed 3 Temperature                               0.889641
# x20:Primary Column Bed 2 Temperature                               0.903873
# x21:Primary Column Bed 1 Temperature                               0.879512
# x22: Secondary Column Base Concentration                          -0.912388
# x23: Flow from Input to Secondary Column                           0.437337
# x24: Secondary Column Tails Flow                                   0.679437
# x25: Secondary Column Tray DP                                      0.717685
# x26: Secondary Column Head Pressure                                0.690348
# x27: Secondary Column Base Pressure                                0.702728
# x28: Secondary Column Base Temperature                             0.800454
# x29: Secondary Column Tray 3 Temperature                           0.578051
# x30: Secondary Column Bed 1 Temperature                            0.698522
# x31: Secondary Column Bed 2 Temperature                            0.747455
# x32: Secondary Column Tray 2 Temperature                           0.457968
# x33: Secondary Column Tray 1 Temperature                           0.604381
# x34: Secondary Column Tails Temperature                            0.906569
# x35: Secondary Column Tails Concentration                         -0.170073
# x36: Feed Column Recycle Flow                                      0.737016
# x37: Feed Column Tails Flow to Primary Column                      0.517494
# x38: Feed Column Calculated DP                                     0.610898
# x39: Feed Column Steam Flow                                        0.713077
# x40: Feed Column Tails Flow                                        0.668859
# Avg_Reactor_Outlet_Impurity                                        0.484338
# Avg_Delta_Composition Primary Column                               0.590445
# y:Impurity                                                         0.310600
# Primary Column Reflux/Feed Ratio                                  -0.039838
# Primary Column Make/Reflux Ratio                                   0.039541
#
#                                                x8:Primary Column Reflux Drum Pressure  \
# Date                                                                        -0.332783
# x1:Primary Column Reflux Flow                                                0.565074
# x2:Primary Column Tails Flow                                                 0.622606
# x3:Input to Primary Column Bed 3 Flow                                        0.319365
# x4:Input to Primary Column Bed 2 Flow                                        0.560686
# x5:Primary Column Feed Flow from Feed Column                                 0.461143
# x6:Primary Column Make Flow                                                  0.408036
# x7:Primary Column Base Level                                                 0.652882
# x8:Primary Column Reflux Drum Pressure                                       1.000000
# x9:Primary Column Condenser Reflux Drum Level                                0.643621
# x10:Primary Column Bed1 DP                                                   0.337567
# x11:Primary Column Bed2 DP                                                   0.347638
# x12:Primary Column Bed3 DP                                                   0.342402
# x13:Primary Column Bed4 DP                                                   0.299839
# x14:Primary Column Base Pressure                                             0.987669
# x15:Primary Column Head Pressure                                             0.999025
# x16:Primary Column Tails Temperature                                         0.094456
# x17:Primary Column Tails Temperature 1                                       0.182059
# x18:Primary Column Bed 4 Temperature                                         0.771384
# x19:Primary Column Bed 3 Temperature                                         0.766630
# x20:Primary Column Bed 2 Temperature                                         0.784043
# x21:Primary Column Bed 1 Temperature                                         0.806614
# x22: Secondary Column Base Concentration                                    -0.637477
# x23: Flow from Input to Secondary Column                                     0.490291
# x24: Secondary Column Tails Flow                                             0.560223
# x25: Secondary Column Tray DP                                                0.505780
# x26: Secondary Column Head Pressure                                          0.984937
# x27: Secondary Column Base Pressure                                          0.983824
# x28: Secondary Column Base Temperature                                       0.634287
# x29: Secondary Column Tray 3 Temperature                                     0.490106
# x30: Secondary Column Bed 1 Temperature                                      0.615740
# x31: Secondary Column Bed 2 Temperature                                      0.677010
# x32: Secondary Column Tray 2 Temperature                                     0.419945
# x33: Secondary Column Tray 1 Temperature                                     0.489920
# x34: Secondary Column Tails Temperature                                      0.708399
# x35: Secondary Column Tails Concentration                                   -0.160808
# x36: Feed Column Recycle Flow                                                0.609575
# x37: Feed Column Tails Flow to Primary Column                                0.409469
# x38: Feed Column Calculated DP                                               0.535567
# x39: Feed Column Steam Flow                                                  0.477483
# x40: Feed Column Tails Flow                                                  0.472016
# Avg_Reactor_Outlet_Impurity                                                  0.237274
# Avg_Delta_Composition Primary Column                                         0.368526
# y:Impurity                                                                   0.218764
# Primary Column Reflux/Feed Ratio                                             0.002466
# Primary Column Make/Reflux Ratio                                             0.014189
#
#                                                x9:Primary Column Condenser Reflux Drum Level  \
# Date                                                                               -0.301012
# x1:Primary Column Reflux Flow                                                       0.788199
# x2:Primary Column Tails Flow                                                        0.884212
# x3:Input to Primary Column Bed 3 Flow                                               0.687136
# x4:Input to Primary Column Bed 2 Flow                                               0.780996
# x5:Primary Column Feed Flow from Feed Column                                        0.722785
# x6:Primary Column Make Flow                                                         0.665838
# x7:Primary Column Base Level                                                        0.893422
# x8:Primary Column Reflux Drum Pressure                                              0.643621
# x9:Primary Column Condenser Reflux Drum Level                                       1.000000
# x10:Primary Column Bed1 DP                                                          0.473206
# x11:Primary Column Bed2 DP                                                          0.493543
# x12:Primary Column Bed3 DP                                                          0.461179
# x13:Primary Column Bed4 DP                                                          0.480511
# x14:Primary Column Base Pressure                                                    0.684696
# x15:Primary Column Head Pressure                                                    0.658942
# x16:Primary Column Tails Temperature                                                0.159802
# x17:Primary Column Tails Temperature 1                                              0.189635
# x18:Primary Column Bed 4 Temperature                                                0.903895
# x19:Primary Column Bed 3 Temperature                                                0.911427
# x20:Primary Column Bed 2 Temperature                                                0.916464
# x21:Primary Column Bed 1 Temperature                                                0.894937
# x22: Secondary Column Base Concentration                                           -0.912919
# x23: Flow from Input to Secondary Column                                            0.463766
# x24: Secondary Column Tails Flow                                                    0.690148
# x25: Secondary Column Tray DP                                                       0.767431
# x26: Secondary Column Head Pressure                                                 0.692908
# x27: Secondary Column Base Pressure                                                 0.707137
# x28: Secondary Column Base Temperature                                              0.815926
# x29: Secondary Column Tray 3 Temperature                                            0.562687
# x30: Secondary Column Bed 1 Temperature                                             0.681911
# x31: Secondary Column Bed 2 Temperature                                             0.734066
# x32: Secondary Column Tray 2 Temperature                                            0.443681
# x33: Secondary Column Tray 1 Temperature                                            0.630241
# x34: Secondary Column Tails Temperature                                             0.915410
# x35: Secondary Column Tails Concentration                                          -0.191509
# x36: Feed Column Recycle Flow                                                       0.778568
# x37: Feed Column Tails Flow to Primary Column                                       0.542581
# x38: Feed Column Calculated DP                                                      0.654300
# x39: Feed Column Steam Flow                                                         0.785139
# x40: Feed Column Tails Flow                                                         0.734560
# Avg_Reactor_Outlet_Impurity                                                         0.498706
# Avg_Delta_Composition Primary Column                                                0.630677
# y:Impurity                                                                          0.297110
# Primary Column Reflux/Feed Ratio                                                   -0.047863
# Primary Column Make/Reflux Ratio                                                    0.026925
#
#                                                ...  \
# Date                                           ...
# x1:Primary Column Reflux Flow                  ...
# x2:Primary Column Tails Flow                   ...
# x3:Input to Primary Column Bed 3 Flow          ...
# x4:Input to Primary Column Bed 2 Flow          ...
# x5:Primary Column Feed Flow from Feed Column   ...
# x6:Primary Column Make Flow                    ...
# x7:Primary Column Base Level                   ...
# x8:Primary Column Reflux Drum Pressure         ...
# x9:Primary Column Condenser Reflux Drum Level  ...
# x10:Primary Column Bed1 DP                     ...
# x11:Primary Column Bed2 DP                     ...
# x12:Primary Column Bed3 DP                     ...
# x13:Primary Column Bed4 DP                     ...
# x14:Primary Column Base Pressure               ...
# x15:Primary Column Head Pressure               ...
# x16:Primary Column Tails Temperature           ...
# x17:Primary Column Tails Temperature 1         ...
# x18:Primary Column Bed 4 Temperature           ...
# x19:Primary Column Bed 3 Temperature           ...
# x20:Primary Column Bed 2 Temperature           ...
# x21:Primary Column Bed 1 Temperature           ...
# x22: Secondary Column Base Concentration       ...
# x23: Flow from Input to Secondary Column       ...
# x24: Secondary Column Tails Flow               ...
# x25: Secondary Column Tray DP                  ...
# x26: Secondary Column Head Pressure            ...
# x27: Secondary Column Base Pressure            ...
# x28: Secondary Column Base Temperature         ...
# x29: Secondary Column Tray 3 Temperature       ...
# x30: Secondary Column Bed 1 Temperature        ...
# x31: Secondary Column Bed 2 Temperature        ...
# x32: Secondary Column Tray 2 Temperature       ...
# x33: Secondary Column Tray 1 Temperature       ...
# x34: Secondary Column Tails Temperature        ...
# x35: Secondary Column Tails Concentration      ...
# x36: Feed Column Recycle Flow                  ...
# x37: Feed Column Tails Flow to Primary Column  ...
# x38: Feed Column Calculated DP                 ...
# x39: Feed Column Steam Flow                    ...
# x40: Feed Column Tails Flow                    ...
# Avg_Reactor_Outlet_Impurity                    ...
# Avg_Delta_Composition Primary Column           ...
# y:Impurity                                     ...
# Primary Column Reflux/Feed Ratio               ...
# Primary Column Make/Reflux Ratio               ...
#
#                                                x36: Feed Column Recycle Flow  \
# Date                                                               -0.297909
# x1:Primary Column Reflux Flow                                       0.689768
# x2:Primary Column Tails Flow                                        0.754131
# x3:Input to Primary Column Bed 3 Flow                               0.619985
# x4:Input to Primary Column Bed 2 Flow                               0.645427
# x5:Primary Column Feed Flow from Feed Column                        0.777537
# x6:Primary Column Make Flow                                         0.703651
# x7:Primary Column Base Level                                        0.737016
# x8:Primary Column Reflux Drum Pressure                              0.609575
# x9:Primary Column Condenser Reflux Drum Level                       0.778568
# x10:Primary Column Bed1 DP                                          0.454014
# x11:Primary Column Bed2 DP                                          0.460210
# x12:Primary Column Bed3 DP                                          0.418497
# x13:Primary Column Bed4 DP                                          0.494673
# x14:Primary Column Base Pressure                                    0.649084
# x15:Primary Column Head Pressure                                    0.625254
# x16:Primary Column Tails Temperature                                0.177660
# x17:Primary Column Tails Temperature 1                              0.109893
# x18:Primary Column Bed 4 Temperature                                0.746452
# x19:Primary Column Bed 3 Temperature                                0.749761
# x20:Primary Column Bed 2 Temperature                                0.770750
# x21:Primary Column Bed 1 Temperature                                0.777231
# x22: Secondary Column Base Concentration                           -0.759750
# x23: Flow from Input to Secondary Column                            0.302661
# x24: Secondary Column Tails Flow                                    0.708905
# x25: Secondary Column Tray DP                                       0.693925
# x26: Secondary Column Head Pressure                                 0.657535
# x27: Secondary Column Base Pressure                                 0.668234
# x28: Secondary Column Base Temperature                              0.686821
# x29: Secondary Column Tray 3 Temperature                            0.522330
# x30: Secondary Column Bed 1 Temperature                             0.596053
# x31: Secondary Column Bed 2 Temperature                             0.629699
# x32: Secondary Column Tray 2 Temperature                            0.287766
# x33: Secondary Column Tray 1 Temperature                            0.605276
# x34: Secondary Column Tails Temperature                             0.764113
# x35: Secondary Column Tails Concentration                          -0.157709
# x36: Feed Column Recycle Flow                                       1.000000
# x37: Feed Column Tails Flow to Primary Column                       0.659945
# x38: Feed Column Calculated DP                                      0.877198
# x39: Feed Column Steam Flow                                         0.877700
# x40: Feed Column Tails Flow                                         0.791423
# Avg_Reactor_Outlet_Impurity                                         0.552417
# Avg_Delta_Composition Primary Column                                0.668411
# y:Impurity                                                          0.284171
# Primary Column Reflux/Feed Ratio                                    0.038791
# Primary Column Make/Reflux Ratio                                    0.084624
#
#                                                x37: Feed Column Tails Flow to Primary Column  \
# Date                                                                               -0.101549
# x1:Primary Column Reflux Flow                                                       0.470948
# x2:Primary Column Tails Flow                                                        0.540855
# x3:Input to Primary Column Bed 3 Flow                                               0.535161
# x4:Input to Primary Column Bed 2 Flow                                               0.569785
# x5:Primary Column Feed Flow from Feed Column                                        0.555507
# x6:Primary Column Make Flow                                                         0.507520
# x7:Primary Column Base Level                                                        0.517494
# x8:Primary Column Reflux Drum Pressure                                              0.409469
# x9:Primary Column Condenser Reflux Drum Level                                       0.542581
# x10:Primary Column Bed1 DP                                                          0.370992
# x11:Primary Column Bed2 DP                                                          0.259703
# x12:Primary Column Bed3 DP                                                          0.146379
# x13:Primary Column Bed4 DP                                                          0.387248
# x14:Primary Column Base Pressure                                                    0.431402
# x15:Primary Column Head Pressure                                                    0.420035
# x16:Primary Column Tails Temperature                                                0.325046
# x17:Primary Column Tails Temperature 1                                              0.206034
# x18:Primary Column Bed 4 Temperature                                                0.531714
# x19:Primary Column Bed 3 Temperature                                                0.532388
# x20:Primary Column Bed 2 Temperature                                                0.535371
# x21:Primary Column Bed 1 Temperature                                                0.555589
# x22: Secondary Column Base Concentration                                           -0.540714
# x23: Flow from Input to Secondary Column                                            0.262998
# x24: Secondary Column Tails Flow                                                    0.706351
# x25: Secondary Column Tray DP                                                       0.360122
# ...
# x30: Secondary Column Bed 1 Temperature                           0.273328
# x31: Secondary Column Bed 2 Temperature                           0.317386
# x32: Secondary Column Tray 2 Temperature                          0.095619
# x33: Secondary Column Tray 1 Temperature                          0.153858
# x34: Secondary Column Tails Temperature                           0.472677
# x35: Secondary Column Tails Concentration                        -0.066998
# x36: Feed Column Recycle Flow                                     0.552417
# x37: Feed Column Tails Flow to Primary Column                     0.449592
# x38: Feed Column Calculated DP                                    0.569529
# x39: Feed Column Steam Flow                                       0.616966
# x40: Feed Column Tails Flow                                       0.761676
# Avg_Reactor_Outlet_Impurity                                       1.000000
# Avg_Delta_Composition Primary Column                              0.886742
# y:Impurity                                                        0.596340
# Primary Column Reflux/Feed Ratio                                 -0.037991
# Primary Column Make/Reflux Ratio                                  0.083768
#
#                                                Avg_Delta_Composition Primary Column  \
# Date                                                                      -0.132035
# x1:Primary Column Reflux Flow                                              0.852385
# x2:Primary Column Tails Flow                                               0.664198
# x3:Input to Primary Column Bed 3 Flow                                      0.638122
# x4:Input to Primary Column Bed 2 Flow                                      0.678863
# x5:Primary Column Feed Flow from Feed Column                               0.930925
# x6:Primary Column Make Flow                                                0.977973
# x7:Primary Column Base Level                                               0.590445
# x8:Primary Column Reflux Drum Pressure                                     0.368526
# x9:Primary Column Condenser Reflux Drum Level                              0.630677
# x10:Primary Column Bed1 DP                                                 0.772547
# x11:Primary Column Bed2 DP                                                 0.803078
# x12:Primary Column Bed3 DP                                                 0.774398
# x13:Primary Column Bed4 DP                                                 0.758304
# x14:Primary Column Base Pressure                                           0.484313
# x15:Primary Column Head Pressure                                           0.403652
# x16:Primary Column Tails Temperature                                       0.228819
# x17:Primary Column Tails Temperature 1                                     0.028109
# x18:Primary Column Bed 4 Temperature                                       0.576671
# x19:Primary Column Bed 3 Temperature                                       0.579595
# x20:Primary Column Bed 2 Temperature                                       0.579887
# x21:Primary Column Bed 1 Temperature                                       0.583296
# x22: Secondary Column Base Concentration                                  -0.568254
# x23: Flow from Input to Secondary Column                                   0.226290
# x24: Secondary Column Tails Flow                                           0.668739
# x25: Secondary Column Tray DP                                              0.512957
# x26: Secondary Column Head Pressure                                        0.497976
# x27: Secondary Column Base Pressure                                        0.505524
# x28: Secondary Column Base Temperature                                     0.500061
# x29: Secondary Column Tray 3 Temperature                                   0.260574
# x30: Secondary Column Bed 1 Temperature                                    0.337990
# x31: Secondary Column Bed 2 Temperature                                    0.407113
# x32: Secondary Column Tray 2 Temperature                                   0.071126
# x33: Secondary Column Tray 1 Temperature                                   0.254124
# x34: Secondary Column Tails Temperature                                    0.596446
# x35: Secondary Column Tails Concentration                                 -0.116041
# x36: Feed Column Recycle Flow                                              0.668411
# x37: Feed Column Tails Flow to Primary Column                              0.503423
# x38: Feed Column Calculated DP                                             0.662513
# x39: Feed Column Steam Flow                                                0.763335
# x40: Feed Column Tails Flow                                                0.916334
# Avg_Reactor_Outlet_Impurity                                                0.886742
# Avg_Delta_Composition Primary Column                                       1.000000
# y:Impurity                                                                 0.618379
# Primary Column Reflux/Feed Ratio                                          -0.047433
# Primary Column Make/Reflux Ratio                                           0.096301
#
#                                                y:Impurity  \
# Date                                             0.011287
# x1:Primary Column Reflux Flow                    0.529820
# x2:Primary Column Tails Flow                     0.277642
# x3:Input to Primary Column Bed 3 Flow            0.328518
# x4:Input to Primary Column Bed 2 Flow            0.383029
# x5:Primary Column Feed Flow from Feed Column     0.592390
# x6:Primary Column Make Flow                      0.580705
# x7:Primary Column Base Level                     0.310600
# x8:Primary Column Reflux Drum Pressure           0.218764
# x9:Primary Column Condenser Reflux Drum Level    0.297110
# x10:Primary Column Bed1 DP                       0.700183
# x11:Primary Column Bed2 DP                       0.589071
# x12:Primary Column Bed3 DP                       0.529492
# x13:Primary Column Bed4 DP                       0.578855
# x14:Primary Column Base Pressure                 0.311114
# x15:Primary Column Head Pressure                 0.244995
# x16:Primary Column Tails Temperature             0.253018
# x17:Primary Column Tails Temperature 1           0.018801
# x18:Primary Column Bed 4 Temperature             0.290649
# x19:Primary Column Bed 3 Temperature             0.297438
# x20:Primary Column Bed 2 Temperature             0.315339
# x21:Primary Column Bed 1 Temperature             0.355093
# x22: Secondary Column Base Concentration        -0.259657
# x23: Flow from Input to Secondary Column         0.125417
# x24: Secondary Column Tails Flow                 0.542934
# x25: Secondary Column Tray DP                    0.012948
# x26: Secondary Column Head Pressure              0.320231
# x27: Secondary Column Base Pressure              0.312500
# x28: Secondary Column Base Temperature           0.246774
# x29: Secondary Column Tray 3 Temperature         0.135058
# x30: Secondary Column Bed 1 Temperature          0.238341
# x31: Secondary Column Bed 2 Temperature          0.315110
# x32: Secondary Column Tray 2 Temperature         0.038899
# x33: Secondary Column Tray 1 Temperature        -0.002439
# x34: Secondary Column Tails Temperature          0.274263
# x35: Secondary Column Tails Concentration       -0.023643
# x36: Feed Column Recycle Flow                    0.284171
# x37: Feed Column Tails Flow to Primary Column    0.375147
# x38: Feed Column Calculated DP                   0.257219
# x39: Feed Column Steam Flow                      0.293745
# x40: Feed Column Tails Flow                      0.578192
# Avg_Reactor_Outlet_Impurity                      0.596340
# Avg_Delta_Composition Primary Column             0.618379
# y:Impurity                                       1.000000
# Primary Column Reflux/Feed Ratio                -0.030571
# Primary Column Make/Reflux Ratio                 0.049644
#
#                                                Primary Column Reflux/Feed Ratio  \
# Date                                                                   0.018953
# x1:Primary Column Reflux Flow                                          0.008352
# x2:Primary Column Tails Flow                                           0.004357
# x3:Input to Primary Column Bed 3 Flow                                 -0.030249
# x4:Input to Primary Column Bed 2 Flow                                 -0.047659
# x5:Primary Column Feed Flow from Feed Column                          -0.054194
# x6:Primary Column Make Flow                                           -0.050222
# x7:Primary Column Base Level                                          -0.039838
# x8:Primary Column Reflux Drum Pressure                                 0.002466
# x9:Primary Column Condenser Reflux Drum Level                         -0.047863
# x10:Primary Column Bed1 DP                                            -0.022732
# x11:Primary Column Bed2 DP                                            -0.022536
# x12:Primary Column Bed3 DP                                            -0.017112
# x13:Primary Column Bed4 DP                                            -0.035068
# x14:Primary Column Base Pressure                                      -0.001632
# x15:Primary Column Head Pressure                                       0.001066
# x16:Primary Column Tails Temperature                                   0.020155
# x17:Primary Column Tails Temperature 1                                -0.037281
# x18:Primary Column Bed 4 Temperature                                   0.005698
# x19:Primary Column Bed 3 Temperature                                   0.005717
# x20:Primary Column Bed 2 Temperature                                   0.003804
# x21:Primary Column Bed 1 Temperature                                   0.003404
# x22: Secondary Column Base Concentration                              -0.004922
# x23: Flow from Input to Secondary Column                              -0.027605
# x24: Secondary Column Tails Flow                                      -0.022752
# x25: Secondary Column Tray DP                                          0.022722
# x26: Secondary Column Head Pressure                                   -0.001941
# x27: Secondary Column Base Pressure                                   -0.000758
# x28: Secondary Column Base Temperature                                 0.001270
# x29: Secondary Column Tray 3 Temperature                               0.008728
# x30: Secondary Column Bed 1 Temperature                                0.004238
# x31: Secondary Column Bed 2 Temperature                               -0.005716
# x32: Secondary Column Tray 2 Temperature                              -0.018227
# x33: Secondary Column Tray 1 Temperature                              -0.013636
# x34: Secondary Column Tails Temperature                                0.001348
# x35: Secondary Column Tails Concentration                             -0.001075
# x36: Feed Column Recycle Flow                                          0.038791
# x37: Feed Column Tails Flow to Primary Column                          0.028015
# x38: Feed Column Calculated DP                                        -0.062135
# x39: Feed Column Steam Flow                                           -0.062171
# x40: Feed Column Tails Flow                                           -0.054940
# Avg_Reactor_Outlet_Impurity                                           -0.037991
# Avg_Delta_Composition Primary Column                                  -0.047433
# y:Impurity                                                            -0.030571
# Primary Column Reflux/Feed Ratio                                       1.000000
# Primary Column Make/Reflux Ratio                                      -0.011273
#
#                                                Primary Column Make/Reflux Ratio
# Date                                                                  -0.026926
# x1:Primary Column Reflux Flow                                          0.049966
# x2:Primary Column Tails Flow                                           0.040210
# x3:Input to Primary Column Bed 3 Flow                                  0.053109
# x4:Input to Primary Column Bed 2 Flow                                  0.047871
# x5:Primary Column Feed Flow from Feed Column                           0.082852
# x6:Primary Column Make Flow                                            0.100181
# x7:Primary Column Base Level                                           0.039541
# x8:Primary Column Reflux Drum Pressure                                 0.014189
# x9:Primary Column Condenser Reflux Drum Level                          0.026925
# x10:Primary Column Bed1 DP                                             0.046661
# x11:Primary Column Bed2 DP                                             0.049944
# x12:Primary Column Bed3 DP                                             0.049225
# x13:Primary Column Bed4 DP                                             0.063908
# x14:Primary Column Base Pressure                                       0.022486
# x15:Primary Column Head Pressure                                       0.016936
# x16:Primary Column Tails Temperature                                   0.016245
# x17:Primary Column Tails Temperature 1                                -0.001633
# x18:Primary Column Bed 4 Temperature                                   0.026859
# x19:Primary Column Bed 3 Temperature                                   0.015757
# x20:Primary Column Bed 2 Temperature                                   0.052777
# x21:Primary Column Bed 1 Temperature                                   0.047791
# x22: Secondary Column Base Concentration                              -0.046145
# x23: Flow from Input to Secondary Column                               0.008908
# x24: Secondary Column Tails Flow                                       0.061345
# x25: Secondary Column Tray DP                                          0.040372
# x26: Secondary Column Head Pressure                                    0.021676
# x27: Secondary Column Base Pressure                                    0.022430
# x28: Secondary Column Base Temperature                                 0.036468
# x29: Secondary Column Tray 3 Temperature                               0.036285
# x30: Secondary Column Bed 1 Temperature                                0.045762
# x31: Secondary Column Bed 2 Temperature                                0.058941
# x32: Secondary Column Tray 2 Temperature                              -0.002955
# x33: Secondary Column Tray 1 Temperature                               0.037433
# x34: Secondary Column Tails Temperature                                0.047531
# x35: Secondary Column Tails Concentration                             -0.016473
# x36: Feed Column Recycle Flow                                          0.084624
# x37: Feed Column Tails Flow to Primary Column                          0.052224
# x38: Feed Column Calculated DP                                         0.122068
# x39: Feed Column Steam Flow                                            0.082100
# x40: Feed Column Tails Flow                                            0.080966
# Avg_Reactor_Outlet_Impurity                                            0.083768
# Avg_Delta_Composition Primary Column                                   0.096301
# y:Impurity                                                             0.049644
# Primary Column Reflux/Feed Ratio                                      -0.011273
# Primary Column Make/Reflux Ratio                                       1.000000
#
# [46 rows x 46 columns]

# %% [markdown]
# This is a lot of data to digest at one time. It is much better to visualize, using a so-called correlation matrix (a N_var x N_var plot with z-colored by correlation). You can do this in Pandas using the built-in print functionality and setting the background color:

# %%
corr.style.background_gradient(cmap='PRGn').format(precision=2)
# Out:
# <style type="text/css">
# #T_2f8cc_row0_col0, #T_2f8cc_row1_col1, #T_2f8cc_row2_col2, #T_2f8cc_row3_col3, #T_2f8cc_row4_col4, #T_2f8cc_row5_col5, #T_2f8cc_row5_col40, #T_2f8cc_row6_col6, #T_2f8cc_row7_col7, #T_2f8cc_row8_col8, #T_2f8cc_row8_col15, #T_2f8cc_row9_col9, #T_2f8cc_row10_col10, #T_2f8cc_row11_col11, #T_2f8cc_row12_col12, #T_2f8cc_row13_col13, #T_2f8cc_row14_col14, #T_2f8cc_row14_col26, #T_2f8cc_row14_col27, #T_2f8cc_row15_col8, #T_2f8cc_row15_col15, #T_2f8cc_row16_col16, #T_2f8cc_row17_col17, #T_2f8cc_row18_col18, #T_2f8cc_row18_col19, #T_2f8cc_row19_col18, #T_2f8cc_row19_col19, #T_2f8cc_row20_col20, #T_2f8cc_row21_col21, #T_2f8cc_row22_col22, #T_2f8cc_row23_col23, #T_2f8cc_row24_col24, #T_2f8cc_row25_col25, #T_2f8cc_row26_col14, #T_2f8cc_row26_col26, #T_2f8cc_row26_col27, #T_2f8cc_row27_col14, #T_2f8cc_row27_col26, #T_2f8cc_row27_col27, #T_2f8cc_row28_col28, #T_2f8cc_row29_col29, #T_2f8cc_row30_col30, #T_2f8cc_row31_col31, #T_2f8cc_row32_col32, #T_2f8cc_row33_col33, #T_2f8cc_row34_col34, #T_2f8cc_row35_col35, #T_2f8cc_row36_col36, #T_2f8cc_row37_col37, #T_2f8cc_row38_col38, #T_2f8cc_row39_col39, #T_2f8cc_row40_col40, #T_2f8cc_row41_col41, #T_2f8cc_row42_col42, #T_2f8cc_row43_col43, #T_2f8cc_row44_col44, #T_2f8cc_row45_col45 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col1, #T_2f8cc_row0_col37, #T_2f8cc_row17_col41, #T_2f8cc_row32_col11, #T_2f8cc_row44_col10, #T_2f8cc_row44_col11 {
#   background-color: #bb9cc9;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col2, #T_2f8cc_row17_col13, #T_2f8cc_row35_col4, #T_2f8cc_row35_col36, #T_2f8cc_row44_col6, #T_2f8cc_row45_col13 {
#   background-color: #d1b8d9;
#   color: #000000;
# }
# #T_2f8cc_row0_col3, #T_2f8cc_row14_col16, #T_2f8cc_row16_col25, #T_2f8cc_row17_col1, #T_2f8cc_row36_col17, #T_2f8cc_row45_col7, #T_2f8cc_row45_col18 {
#   background-color: #f7f6f7;
#   color: #000000;
# }
# #T_2f8cc_row0_col4, #T_2f8cc_row35_col15, #T_2f8cc_row35_col23 {
#   background-color: #c0a2cd;
#   color: #000000;
# }
# #T_2f8cc_row0_col5, #T_2f8cc_row17_col43 {
#   background-color: #a17ab2;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col6, #T_2f8cc_row1_col0 {
#   background-color: #966ba8;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col7, #T_2f8cc_row16_col32, #T_2f8cc_row44_col38 {
#   background-color: #d4bcdb;
#   color: #000000;
# }
# #T_2f8cc_row0_col8, #T_2f8cc_row6_col22, #T_2f8cc_row35_col43 {
#   background-color: #9465a5;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col9, #T_2f8cc_row17_col11, #T_2f8cc_row35_col5, #T_2f8cc_row45_col12 {
#   background-color: #c9add3;
#   color: #000000;
# }
# #T_2f8cc_row0_col10, #T_2f8cc_row0_col43, #T_2f8cc_row25_col43, #T_2f8cc_row37_col22 {
#   background-color: #9f78b1;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col11, #T_2f8cc_row8_col22, #T_2f8cc_row28_col0 {
#   background-color: #8d579d;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col12, #T_2f8cc_row3_col22, #T_2f8cc_row24_col22, #T_2f8cc_row25_col0 {
#   background-color: #803f8f;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col13, #T_2f8cc_row4_col44, #T_2f8cc_row9_col44, #T_2f8cc_row18_col22, #T_2f8cc_row19_col22, #T_2f8cc_row28_col35, #T_2f8cc_row34_col35, #T_2f8cc_row42_col44 {
#   background-color: #460552;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col14, #T_2f8cc_row42_col22 {
#   background-color: #9970ab;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col15, #T_2f8cc_row2_col0 {
#   background-color: #9568a6;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col16, #T_2f8cc_row9_col43, #T_2f8cc_row17_col5, #T_2f8cc_row19_col43, #T_2f8cc_row43_col23, #T_2f8cc_row45_col16 {
#   background-color: #eee3ee;
#   color: #000000;
# }
# #T_2f8cc_row0_col17, #T_2f8cc_row10_col32, #T_2f8cc_row43_col22, #T_2f8cc_row43_col32 {
#   background-color: #d8c2de;
#   color: #000000;
# }
# #T_2f8cc_row0_col18, #T_2f8cc_row0_col19, #T_2f8cc_row35_col14, #T_2f8cc_row35_col33, #T_2f8cc_row41_col23 {
#   background-color: #c3a6cf;
#   color: #000000;
# }
# #T_2f8cc_row0_col20, #T_2f8cc_row0_col21, #T_2f8cc_row29_col43 {
#   background-color: #c7abd2;
#   color: #000000;
# }
# #T_2f8cc_row0_col22, #T_2f8cc_row3_col14, #T_2f8cc_row12_col15, #T_2f8cc_row12_col24, #T_2f8cc_row12_col31, #T_2f8cc_row15_col37, #T_2f8cc_row20_col12, #T_2f8cc_row24_col23, #T_2f8cc_row31_col42, #T_2f8cc_row36_col11, #T_2f8cc_row37_col41, #T_2f8cc_row41_col27, #T_2f8cc_row43_col2 {
#   background-color: #cdebc7;
#   color: #000000;
# }
# #T_2f8cc_row0_col23, #T_2f8cc_row2_col35, #T_2f8cc_row16_col17, #T_2f8cc_row17_col16, #T_2f8cc_row22_col1, #T_2f8cc_row22_col2, #T_2f8cc_row22_col3, #T_2f8cc_row22_col4, #T_2f8cc_row22_col5, #T_2f8cc_row22_col6, #T_2f8cc_row22_col7, #T_2f8cc_row22_col8, #T_2f8cc_row22_col9, #T_2f8cc_row22_col10, #T_2f8cc_row22_col11, #T_2f8cc_row22_col12, #T_2f8cc_row22_col13, #T_2f8cc_row22_col14, #T_2f8cc_row22_col15, #T_2f8cc_row22_col18, #T_2f8cc_row22_col19, #T_2f8cc_row22_col20, #T_2f8cc_row22_col21, #T_2f8cc_row22_col24, #T_2f8cc_row22_col25, #T_2f8cc_row22_col26, #T_2f8cc_row22_col27, #T_2f8cc_row22_col28, #T_2f8cc_row22_col29, #T_2f8cc_row22_col30, #T_2f8cc_row22_col31, #T_2f8cc_row22_col32, #T_2f8cc_row22_col33, #T_2f8cc_row22_col34, #T_2f8cc_row22_col36, #T_2f8cc_row22_col37, #T_2f8cc_row22_col38, #T_2f8cc_row22_col39, #T_2f8cc_row22_col40, #T_2f8cc_row22_col41, #T_2f8cc_row22_col42, #T_2f8cc_row22_col43, #T_2f8cc_row22_col45, #T_2f8cc_row23_col0, #T_2f8cc_row34_col22, #T_2f8cc_row38_col44, #T_2f8cc_row39_col44 {
#   background-color: #40004b;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col24, #T_2f8cc_row0_col32, #T_2f8cc_row33_col10, #T_2f8cc_row35_col39, #T_2f8cc_row45_col10 {
#   background-color: #cdb3d6;
#   color: #000000;
# }
# #T_2f8cc_row0_col25, #T_2f8cc_row29_col0, #T_2f8cc_row32_col13, #T_2f8cc_row35_col13, #T_2f8cc_row38_col0, #T_2f8cc_row45_col43 {
#   background-color: #ab87bb;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col26, #T_2f8cc_row31_col0, #T_2f8cc_row33_col43 {
#   background-color: #9b72ac;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col27, #T_2f8cc_row7_col0 {
#   background-color: #9c74ae;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col28, #T_2f8cc_row35_col6, #T_2f8cc_row37_col0 {
#   background-color: #c1a4ce;
#   color: #000000;
# }
# #T_2f8cc_row0_col29, #T_2f8cc_row0_col36, #T_2f8cc_row33_col12 {
#   background-color: #b391c2;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col30, #T_2f8cc_row12_col22, #T_2f8cc_row35_col8, #T_2f8cc_row35_col29, #T_2f8cc_row44_col41 {
#   background-color: #bea0cb;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col31, #T_2f8cc_row10_col0, #T_2f8cc_row13_col32, #T_2f8cc_row35_col37, #T_2f8cc_row35_col42 {
#   background-color: #bc9eca;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col33, #T_2f8cc_row0_col40, #T_2f8cc_row30_col0 {
#   background-color: #a37cb3;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col34, #T_2f8cc_row35_col1, #T_2f8cc_row44_col23, #T_2f8cc_row45_col0 {
#   background-color: #d3bada;
#   color: #000000;
# }
# #T_2f8cc_row0_col35 {
#   background-color: #9e76af;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col38, #T_2f8cc_row11_col22, #T_2f8cc_row17_col12, #T_2f8cc_row24_col0, #T_2f8cc_row35_col41, #T_2f8cc_row44_col12, #T_2f8cc_row44_col13 {
#   background-color: #b695c4;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col39, #T_2f8cc_row11_col0 {
#   background-color: #a985b9;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col41, #T_2f8cc_row17_col3, #T_2f8cc_row17_col37, #T_2f8cc_row21_col43, #T_2f8cc_row23_col32, #T_2f8cc_row30_col13, #T_2f8cc_row30_col16, #T_2f8cc_row38_col32, #T_2f8cc_row44_col18, #T_2f8cc_row44_col19 {
#   background-color: #f5f2f5;
#   color: #000000;
# }
# #T_2f8cc_row0_col42, #T_2f8cc_row17_col0, #T_2f8cc_row35_col38, #T_2f8cc_row42_col0 {
#   background-color: #b99ac7;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col44, #T_2f8cc_row16_col44 {
#   background-color: #681f75;
#   color: #f1f1f1;
# }
# #T_2f8cc_row0_col45, #T_2f8cc_row9_col35, #T_2f8cc_row21_col22, #T_2f8cc_row25_col35 {
#   background-color: #480754;
#   color: #f1f1f1;
# }
# #T_2f8cc_row1_col2, #T_2f8cc_row2_col28, #T_2f8cc_row14_col21, #T_2f8cc_row28_col2, #T_2f8cc_row28_col21, #T_2f8cc_row39_col5, #T_2f8cc_row39_col40, #T_2f8cc_row42_col1 {
#   background-color: #166f32;
#   color: #f1f1f1;
# }
# #T_2f8cc_row1_col3, #T_2f8cc_row2_col42, #T_2f8cc_row3_col25, #T_2f8cc_row3_col28, #T_2f8cc_row3_col41, #T_2f8cc_row4_col27, #T_2f8cc_row5_col28,

# %% [markdown]
# More succinctly, you can use matplotlib to make an actual plot of the matrix using the `plt.matshow` function:

# %%
plt.figure(figsize=(8,8))
plt.matshow(corr,fignum=0) # atypical behavior, makes a new fig by default, 0 adds to current
plt.colorbar() # add colorbar
plt.title('Correlation Matrix', fontsize=16)
plt.show()

# %% [markdown]
# Two things are universal about these plots. First, the matrix is symmetric (i.e., $A=A^\mathrm{T}$), because $r_{xy}=r_{yx}$. So only half of the matrix holds unique information. Second, there is a bright strip of yellow along the diagonal, corresponding to a correlation of 1. This is because $r_{xx}=1$ by definition.
#
# More significantly for this dataset, we also see a lot of bright yellow patches and dark purple patches along the off diagonal. These correspond to situations where the variables are strongly correlated, or anti-correlated. For the purposes of building a model, this means that these variables hold redundant information. If you know what one is, then you can predict what the other is (depending on the level of correlation), this might form a basis for removing  variables from a model.
#
# Since we are interested in impurity, let's take a look at the five most linearly correlated features with `y:Impurity`:

# %%
# Check the five most linearly correlated variables with impurity
print("y-correlations:\n")
lab = corr['y:Impurity'].abs().nlargest(6).index
print(corr['y:Impurity'][lab[1:]])
# Out:
# y-correlations:
#
# x10:Primary Column Bed1 DP                      0.700183
# Avg_Delta_Composition Primary Column            0.618379
# Avg_Reactor_Outlet_Impurity                     0.596340
# x5:Primary Column Feed Flow from Feed Column    0.592390
# x11:Primary Column Bed2 DP                      0.589071
# Name: y:Impurity, dtype: float64

# %% [markdown]
# Here I have used the `abs` method so that we find the largest <i>magnitude</i> correlations, not just positive correlations. I've also returned the top 6 correlated variables, and thrown out the first, because `y:impurity` is trivially the most correlated variable with itself. None of these show a particularly strong correlation individually (in keeping with this being a challenging prediction problem).
#
# A second plot that is useful for visualizing correlations is a parity plot, where we plot two variables against one another:

# %%
plt.figure(figsize=(12,3))
for count_i,i in enumerate(lab[1:]):
    ax = plt.subplot(1,5,count_i+1)
    plt.scatter(dow["y:Impurity"],dow[i],alpha=0.2)
    plt.title("r={:4.2f}".format(corr.loc['y:Impurity'][i]))
    plt.xlabel("Impurity")
    plt.ylabel(i)
plt.tight_layout() # Useful for removing overlaps in subplots
plt.show()

# %% [markdown]
# This is already quite useful, but it would be nice to have the color of the points reflect the density of points in each region. Recall from the matplotlib lecture that a kernel density estimate (kde) is a flexible tool for this job. A KDE is a model that approximates the probability of sampling datapoints as a continuous function. After we have this fix, we have a continous estimate of the data density at each datapoint (and elsewhere). Here we will use the `KernelDensity` class from `sklearn.neighbors` which is more flexible than the `scipy` function that we used in the earlier lecture. Let's import this, fit the kde, and replot.

# %%
from sklearn.neighbors import KernelDensity
import matplotlib.cm as cm

plt.figure(figsize=(12,3))
for count_i,i in enumerate(lab[1:]): 
    kde = KernelDensity().fit(dow[["y:Impurity",i]])
    d = np.e**(kde.score_samples(dow[["y:Impurity",i]]))
    ax = plt.subplot(1,5,count_i+1)
    plt.scatter(dow["y:Impurity"],dow[i],c=cm.viridis(abs(d)/max(abs(d))))
    plt.title("r={:4.2f}".format(corr.loc['y:Impurity'][i]))
    plt.xlabel("Impurity")
    plt.ylabel(i)
plt.tight_layout() # Useful for removing overlaps in subplots
plt.show()

# %% [markdown]
# <b>Note:</b> performing the KDE in high dimensions and lots of data quickly gets expensive. You probably noticed that running the last cell took a lot longer than the case without the KDE.
#
# <b>Note:</b> the `KernelDensity.score_samples()` method returns the natural logarithm of the probability of each sample. That's why we have taken this value and exponentiated it.
#
# We also saw in the correlation matrix that several of the variables were correlated with one another. Let's find the five most correlated pairs of variables:

# %%
# Find linearly correlated features 
# There is probably a solution with Pandas .where() that is workable as well. I'm more comfortable with arrays.
corr_array = corr.abs().to_numpy()[:-5,:-5] # return a numpy array with only absolute values of "xINT:" variables
row,col = np.where((corr_array > 0.95) & (corr_array < 1)) # find positions where correlation mags are >0.95 and !=1
labels = [ (corr.index[row[_]],corr.columns[col[_]]) for _ in range(len(row)) if row[_] > col[_] ] # find labels/cols

### Correlation Grid of features
plt.figure(figsize=(12,12))
inc = -1
for i in range(len(labels)):

  # Comment kde out if it is too expensive
  kde = KernelDensity().fit(dow[[labels[i][0],labels[i][1]]])
  d = np.e**(kde.score_samples(dow[[labels[i][0],labels[i][1]]]))
    
  # Make the parity plot within the subplot space
  ax = plt.subplot(5,5,i+1)
  ax.scatter(dow.loc[:,labels[i][0]],dow.loc[:,labels[i][1]],c=cm.viridis(abs(d)/max(abs(d))))
  ax.set_title("R = {:<3.2f}".format(corr.loc[labels[i][0],labels[i][1]]))
  ax.set_xlabel(labels[i][0].split(":")[0])
  ax.set_ylabel(labels[i][1].split(":")[0])
plt.tight_layout()
plt.show()

# %% [markdown]
# We've just uncovered a lot of interesting relationships. First, there are several variables that are strongly correlated and likely redundant (e.g., `x8`,`x14`,`x15`,`x26`, and `x27` which all correspond to pressure in different unit ops).
#
# Second, we also see strong linear correlations among variables whose parity plots contain obvious outliers. For example, in the `x11` vs `x12` plot there is a strong correlation, but there are a small number of outliers that throw off the axes. Plotting with transparent markers helps to identify these as low density compared with the overwhelming linear trend.
#
# Third, we also see several cases where there is a strong linear correlation, but sparse data. For example, `x34` vs `x18` has a strong correlation ($r=0.97$) but when we inspect the plot, we see that this linear correlation is driven by essentially two discrete values:

# %%
# Save the original header labels and rename working labels
h_0 = dow.columns
dow.columns = [ _.split(':')[0] for _ in dow.columns ]

# Make the plot
plt.scatter(dow["x18"],dow["x34"],alpha=0.2)
plt.xlabel("x18")
plt.ylabel("x34")
plt.show()

# %% [markdown]
# These variables correspond to the temperature in the beds of the primary and secondary column. There is a large density of points at ~(20,20) and ~(50,140) respectively, with hardly any values in between. We know from our friends at Dow that some of the units were off during the time we have data for. Looking at this plot we might guess that the "off-temperature" of both is ambient ~20C (and strongly correlated), and the target "on-temperature" is 50C and 140C respectively. Their strong correlation comes from the fact that they were off or on at the same times, not that they varied linearly during operation.

# %% [markdown]
# ## Removing Outliers
# Removing outliers (i.e., samples that we consider unrepresentative or not a true member of the population we are investigating) is highly problem specific and there are no black-box methods that should be universally used. This is because classifying something as an outlier depends on 1) your <b>domain knowledge</b> of what the data represents, 2) what you want to <b>predict</b> from the data, and 3) your <b>model</b> of the data.
#
# Taking each in order, your domain knowledge plays an important role in understanding if something is an outlier. In the Dow example, we have sensor data on many variables, including things like pressure, concentration, and temperature, as a function of time. Our domain knowledge includes our understanding of how these variables are capable of changing in time. For example, our understanding of physics tells us that pressure can change very quickly, while large temperature changes will be limited by the heat capacities and thermal conductivities of the components. We would consult this knowledge when considering whether a sudden large fluctuation in temperature or pressure were "real" or an "outlier" that should be removed from our dataset. These kinds of references to domain knowledge are extremely common in identifying outliers, and are by definition left out when naively applying a one-size-fits-all method.
#
# Second, what we want to predict also determines what data we might classify as outliers. Suppose we only want to predict seasonal trends. In that case, we might discard large fluctuations in certain variables that only occur over short time periods before trying to build our model. In this case, we would be classifying samples as outliers or replacing them, <i>not because they are unphysical</i>, but because they are unimportant with respect to our prediction target. The reference to our prediction objective is another reason why a one-size-fits-all approach does not exist.
#
# Third, our model of the data will often influence what we consider an outlier. For example, typical outlier classification procedures depend on calculating a z-score (i.e., a normalized magnitude of the deviation from normal/gaussian behavior) for each observation and removing values that are larger than some threshold. In such a procedure, we are assuming that our variable should obey gaussian statistics. We may have good reason for assuming this (point 1), or it may just be a convenient way of modeling the random variable (related to point 2). But in this case, we would be classifying outliers based on <b>our model of the data</b>, not because we necessarily had evidence that the sample was unphysical or incorrect. Keeping track of our model of the data (and the assumptions that come along with that model) is an important factor in applying any outlier removal algorithm. All outlier classifications have assumptions that may or may not be applicable to our problem, this is another reason why a one-size-fits-all approach does not exist.
#
# ### Robust Z-Score
# The simplest methods for identifying outliers assume that data obeys normal statistics. Under circumstances where the central limit theorem applies (i.e., observables that are plausibly governed by a large number of independent stochastic factors), normal statistics are expected. Likewise, even when the central limit doesn't necessaarily obtain, the corresponding distribution may be sufficiently normal to justify approximation with a gaussian. Finally, you may sometimes simply assume normal statistics for convenience while understanding that you may be throwing out real values. Regardless of the circumstances, you should think carefully when you use any method that assumes an underlying data distribution. In particular, just because you might see normal statistics assumed in the literature without justification does not mean it is right!
#
# When assuming normal statistics, a typical approach for classifying outliers is based on whether a sample deviates from the mean beyond a given threshold. The z-score of a sample is the deviation from the mean normalized by the standard deviation:
#
# $$z_{i} = \frac{x_{i} - \mu_x}{\sigma_x}$$
#
# Under the hypothesis that the data obeys normal statistics, the z-score can be related to the probability of observation using the cumulative normal distribution function. For example, 68% of samples would have a z-score between -1 and 1, 95% between -2 and 2, and 99.7% between -3 and 3. If you observe a sample with a z-score of 4 in a dataset of 100 values, you might reasonably conclude that this is an outlier and would want to remove it or replace it (usually with the mean or median).
#
# This sounds simple: we just need to calculate the z-scores, compare with a threshold, and then replace or remove the outliers. However, if outliers <i>are</i> in the sample, then they will affect the calculation of the mean ($\mu_x$) and standard deviation ($\sigma_x$). How can we calculate the mean from a sample that contains outliers? This is the motivation for the <b>robust z-score</b>. The fundamental observation is that the <b>median</b> of a sample is an <b>unbiased estimator</b> for the mean. Although the sample mean is typically the most efficient estimator of the population mean, <i>the median is much less affected by outliers</i>. We can calculate a (robust) z-score based on the sample median instead of the mean as:
#
# $$z_{i} = \frac{\left|x_{i}-\mathrm{med}(X)\right|}{1.4826 \cdot MAD}$$
#
# $$MAD=\mathrm{med}(X-\mathrm{med}(X))$$
#
# Here the MAD is the median absolute deviation from the median ($\mathrm{med}(X)$), and the factor $1.4296$ is a scale factor that relates the MAD to the standard deviation (in this case assuming a gaussian distribution, for other distributions a different scale factor would be used).
#
# When utilizing the robust z-score for time-series data, it makes the most physical sense to apply it to a running window of values. For each sample, one calculates the robust z-score for the center of the window. If the robust z-score exceeds a threshold then the value is replaced by the median of the window. This strategy for removing outliers from time-series data is known as a <b>Hampel Filter</b>. We can easily implement one ourselves in python:

# %%
# X:       data as a numpy array,
# w:       window size for median calculation (+/- this number of samples)
# n_sig:   float holding the threshold number of sigma values to use as a cutoff for classifying outliers
# k:       scale factor for converting MAD to stdev (default: 1.4826 for normal distribution)
def hampel(x,w,n_sig=3.0,k=1.4826):

    # Check that the length is at least 2w
    assert len(x) > 2*w,"x isn't long enough to filter"

    # Copy array so that updates don't conflict with median calulation
    y = x.copy() 

    # Calculate length and initialize lists
    N = len(y)
    z = [0.0]*N    # list for holding z-scores
    o = [False]*N  # list of holding True/False outlier spec
    for i in range(w,N-w):
        med  = np.median(x[i-w:i+w+1])
        mad  = k*np.median(np.abs(x[i-w:i+w+1]-med))
        z[i] = np.abs(x[i]-med)/mad
        if z[i] > n_sig:
            y[i] = med
            o[i] = True

    return y,z,o

# %% [markdown]
# Let's apply it to the dow dataset with a few values of threshold and see which values it identifies as outliers.

# %%
for i in np.arange(1.0,5.0):
    y,z,o = hampel(dow["y"].to_numpy(),w=100,n_sig=i)
    print("n_sig={}: {} outliers ({:<4.2f}%)".format(i,sum(o),sum(o)/float(len(o)*100.0)))
    plt.figure(figsize=(12,3))
    o_inds = [ count for count,_ in enumerate(o) if _ is True ]
    i_inds = [ count for count,_ in enumerate(o) if _ is False ]

    # Plot original data with outliers marked
    plt.figure(figsize=(12,3))
    plt.plot(dow.iloc[o_inds,0],dow.iloc[o_inds,-3],marker='o',color=(0.1,0.8,0.4),linestyle='None')
    plt.plot(dow.iloc[i_inds,0],dow.iloc[i_inds,-3],color="k")
    plt.xlabel("time")
    plt.ylabel("y:Impurity")
    plt.title("original with outliers ({:d}, {:<4.2f}%) marked".format(sum(o),sum(o)/float(len(o))*100.0))
    
    # Plot original data with outliers replaced by median
    plt.figure(figsize=(12,3))
    plt.plot(dow.iloc[:,0],y,color="k")
    plt.xlabel("time")
    plt.ylabel("y:Impurity")
    plt.title("outliers ({:d}, {:<4.2f}%) replaced by median".format(sum(o),sum(o)/float(len(o))*100.0))
    
    plt.show()
# Out:
# n_sig=1.0: 2157 outliers (0.00%)
# n_sig=2.0: 545 outliers (0.00%)
# n_sig=3.0: 263 outliers (0.00%)
# n_sig=4.0: 160 outliers (0.00%)

# %% [markdown]
# The above cell demonstrates the typical behavior for a Hampel filter: it successfully identifies large fluctuations and replaces them with the median. As the `n_sig` parameter decreases, more data is removed. This behavior is intuitive and is often exactly what we want. However, in all cases we end up removing the large impurity peak that occured ~2016-12. <i>Is this what we want?</i> If you were trying to improve the plant and that reading is real, isn't that precisely the kind of event that you would want to predict? Classifying large but real fluctations as outliers is a danger of the Hampel filter. It is possible that we could still build a predictive model, even without this data, but we might be leaving a critical source of information out.

# %% [markdown]
# ### Principal Component Analysis (PCA)
# PCA is an important method for identifying "important" dimensions in a high dimensional dataset. Specifically, PCA analysis performs a rotation of the data into a coordinate frame where the greatest variance occurs along the first dimension (PC1), the next greatest variance occurs along the second principle dimension (PC2), and so on. Here we will use PCA to visualize our large dimensional Dow dataset along a new set of dimensions that capture the most variance in the data. Although, PCA isn't itself a method for identifying outliers, in a case like the Dow dataset where we expect the data to be contaminated by periods where units are off, we can potentially use PCA to identify where this occurs in the feature (`x:`) space.
#
# #### Simple Example
# Before getting into specifics, let's look at an illustration of what PCA does to a two-dimensional dataset based on gaussian distributed x and y values:

# %%
# Generate the data
np.random.seed(92425) # for reproducibility
x = np.random.normal(loc=10,scale=20,size=10000)
y = np.random.normal(loc=10,scale=5,size=10000)
sample = np.vstack([x,y]).T

# Make a scatterplot
plt.figure()
plt.scatter(sample[:,0],sample[:,1],alpha=0.2)
plt.title("original data")
plt.xlabel("x")
plt.ylabel("y")

# Rotate the data
rad = -np.pi/4.0
rot = np.array([[np.cos(rad),-np.sin(rad)],[np.sin(rad),np.cos(rad)]])
sample = np.dot(sample,rot)

# Make a scatterplot
plt.figure()
plt.scatter(sample[:,0],sample[:,1],alpha=0.2)
plt.title("rotated data")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# The resulting dataset is normally distributed along the two diagonals. What PCA does is find the vector that captures the most variance and assigns it to first "principle component" (PC1), then finds the next vector that is orthogonal to the PC1 that captures the next most variance and assigns it to PC2, and so on for higher dimensional datasets. For the current dataset, we would expect PC1 to be the unit vector along (1,1) and PC2 to be the unit vector along (1,-1) (the sign is ambiguous, each can be multiplied by -1 and still correspond to the same direction).
#
# Let's write our own PCA algorithm (explanation will be deferred until later on):

# %%
# Our own PCA function
def pca(X,std=True):
  
  # remove mean from each column
  Xmean = X.mean(axis=0)
  TMP = X - Xmean

  # Normalize columns by standard deviation
  if std:
      TMP = TMP/TMP.std(axis=0)
    
  # Compute the covariance matrix
  C = np.dot(TMP.T, TMP) / ((len(TMP[0])-1)*len(TMP))

  # Perform the Eigen decomposition
  evals, evecs = np.linalg.eig(C)
  ind = np.argsort(evals)[::-1] # sort descending
  evals = evals[ind] # sort evals
  evecs = evecs[:,ind] # sort evecs

  # Project X onto PC space, scale by std, and add back the mean
  X_pca = np.dot(TMP, evecs)
  X_pca = X_pca + np.dot(Xmean,evecs)

  return X_pca,evecs,evals

# %% [markdown]
# Now let's plot the results of the transformed data and the principle components:

# %%
sample_pca,PCs,vars = pca(sample)
# Make a scatterplot
plt.scatter(sample_pca[:,0],sample_pca[:,1],alpha=0.2)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# Here the `pca()` function that we've written returns the original data, but rotated to align with the principle components (`sample_pca`). When we plot this data we see that the largest variance lies along PC1 and the second largest variance lies along PC2. Note, by default PC analyses typically rescale each dimension by its variance before performing the transformation to control for potential differences in units, relative variances are still conserved.
#
# So what has PCA done? For an N-dimensional dataset, it finds a set $\mathbf{N}'$ of new vectors (the principal components). The vectors $\mathbf{N}'$ are required to be (i) orthogonal to one another, and (ii) linear combinations of the original $\mathbf{N}$ vectors. More usefully, the vectors in $\mathbf{N}'$ are selected so that the data shows the largest possible variance along $N'_1$ (i.e., PC1); then given $N'_1$, $N'_2$ is selected to be orthogonal to $N'_1$ and so that the data shows the largest possible variance along $N'_2$; then given $N'_1$ and $N'_2$, $N'_3$ is selected to be orthogonal to $N'_1$ and $N'_2$ and so that the data shows the largest possible variance along $N'_3$; and so on.

# %% [markdown]
# #### Additional Details (optional)
# I've told you <i>what</i> PCA does, but not <i>how</i> it does it. Given the broad composition of the students in this course, you may not have the linear algebra background required to fully understand the details. In brief, consider a dataset with $M$ samples and $N$ variables (e.g., $N$ sensor readings at $M$ times). After centering the data about $\mathbf{0}$, the covariance matrix
#
# $$ \mathbf{C} = \frac{\mathbf{X}^\mathrm{T}\mathbf{X}}{(N-1)(M)} $$
#
# holds the covariance of the data along variable $i$ and $j$ at the position $C_{ij}$, where $C_{ii}$ is the variance along is specific direction $i$. This matrix has all of the information we need to find our principle components: it has the variances and covariances and these are the things we are trying to maximize in our new direction vectors (the PCs). It can be shown that the eigenvectors of $C$, sorted by their eigenvalue, are the PCs we are after. After the eigendecomposition of C
#
# $$ \mathbf{C} = \mathbf{W}\mathbf{\Lambda}\mathbf{W}^\mathrm{T} $$
#
# the matrix $\mathbf{W}$ (NxN) holds the eigenvectors of $\mathbf{C}$ along its columns and $\mathbf{\Lambda}$ (NxN) is a matrix with the eigenvalues of $\mathbf{C}$ along its diagonal and zeros elsewhere. Revisiting the function that we wrote:

# %%
# Our own PCA function
def pca(X,std=True):
  
  # remove mean from each column
  Xmean = X.mean(axis=0)
  TMP = X - Xmean

  # Normalize columns by standard deviation
  if std:
      TMP = TMP/TMP.std(axis=0)
    
  # Compute the covariance matrix
  C = np.dot(TMP.T, TMP) / ((len(TMP[0])-1)*len(TMP))

  # Perform the Eigen decomposition
  evals, evecs = np.linalg.eig(C)
  ind = np.argsort(evals)[::-1] # sort descending
  evals = evals[ind] # sort evals
  evecs = evecs[:,ind] # sort evecs

  # Project X onto PC space, scale by std, and add back the mean
  X_pca = np.dot(TMP, evecs)
  X_pca = X_pca + np.dot(Xmean,evecs)

  return X_pca,evecs,evals

# %% [markdown]
# You can see that we take in a data matrix `X` then (1) subtract the mean of each column to center the data about $\mathbf{0}$, (2) normalize by the standard deviation of each column (controls for units) (3) calculate the covariance matrix, (4) calculate the eigendecomposition using the `np.linalg.eig()` function, (5) sort the eigenvalues and eigenvectors in descending order (`np.argsort()` commands), (6) project the original data onto our new vectors (`np.dot(TMP,evecs)`), (7) (optionally, not always done) add back the mean of each column in the transformed coordinates (`X_pca + np.dot(Xmean,evecs)`), and (8) return the transformed data, eigenvector/PCs, and eigenvalues. Here we have relied on the fact that `np.linalg.eig()` returns normalized eigenvectors. Additionally, the reason that we normalize the columns by the standard deviation is that this controls for different scales in the data that might simply be an artifact of units (e.g., if one column was in mg and another was in kg, the column in mg might exhibit a larger variance due solely to its smaller units).
#
# Why do we bother returning the eigenvalues? These are actually informative, since they hold the variance along each PC after the transformation:

# %%
sample_pca,PCs,vars = pca(sample)
print("PCs (along columns):\n{}\n".format(PCs))
print("evals:\n{}\n".format(vars))
print("variance:\n{}\n".format(sample_pca.std(axis=0)**(2.0)))
# Out:
# PCs (along columns):
# [[-0.70710678 -0.70710678]
#  [-0.70710678  0.70710678]]
#
# evals:
# [1.88180043 0.11819957]
#
# variance:
# [1.88180043 0.11819957]

# %% [markdown]
# In the above cell we compare the eigenvalues with the variance of the transformed data (calculated explicitly) and see that they are equal. An alternative way of using the eigenvalues is to report each normalized by the sum of eigenvalues, which tells you what fraction of the total variance in the data is described by each PC.

# %%
tot = sum(vars)/100.0 
for count_i,i in enumerate(vars):
    print("PC{}: {: 6.2f} ({:4.2f}%)".format(count_i+1,i,i/tot))
# Out:
# PC1:   1.88 (94.09%)
# PC2:   0.12 (5.91%)

# %% [markdown]
# #### PCA - Dow Dataset
# Now that we've gone over the basics of PCA let's use it to help analyze the Dow dataset. In particular, this is a relatively large dataset, with many descriptor variables (`x:`). When we were previously discussing correlations, we found some interesting results when we looked at pairs of the most correlated variables, but we were limited from exhaustively exploring these relationships by the sheer number of variables. This is where PCA becomes useful.
#
# By transforming the data that we've been given from a coordinate frame defined by the `x:` variables into a coordinate frame of PCs, we can focus on the dimensions that explain most of the variance in the data. Let's calculate the PCs  for our dataset:

# %%
dow_x = dow.iloc[:,1:41].to_numpy() # grab the x-data 
dow_x_pca,PCs,vars = pca(dow_x) # PCA analysis

# Make a scatterplots of first three principle components
plt.figure(figsize=(15,5))
ax = plt.subplot(1,3,1)
ax.scatter(dow_x_pca[:,0],dow_x_pca[:,1],alpha=0.2)
ax.set_xlabel("PC1 ({:<4.2f}%)".format(vars[0]/sum(vars)*100.0))
ax.set_ylabel("PC2 ({:<4.2f}%)".format(vars[1]/sum(vars)*100.0))

ax = plt.subplot(1,3,2)
ax.scatter(dow_x_pca[:,0],dow_x_pca[:,2],alpha=0.2)
ax.set_xlabel("PC1 ({:<4.2f}%)".format(vars[0]/sum(vars)*100.0))
ax.set_ylabel("PC3 ({:<4.2f}%)".format(vars[2]/sum(vars)*100.0))

ax = plt.subplot(1,3,3)
ax.scatter(dow_x_pca[:,1],dow_x_pca[:,2],alpha=0.2)
ax.set_xlabel("PC2 ({:<4.2f}%)".format(vars[1]/sum(vars)*100.0))
ax.set_ylabel("PC3 ({:<4.2f}%)".format(vars[2]/sum(vars)*100.0))

plt.show()

# %%
dow_x = dow.iloc[:,1:41].to_numpy() # grab the x-data 
dow_x_pca,PCs,vars = pca(dow_x) # PCA analysis

# Make a scatterplots of first three principle components
plt.figure(figsize=(15,5)) 
ax = plt.subplot(1,3,1)
kde = KernelDensity().fit(dow_x_pca[:,[0,1]])
d = np.e**(kde.score_samples(dow_x_pca[:,[0,1]]))
ax.scatter(dow_x_pca[:,0],dow_x_pca[:,1],c=cm.viridis(abs(d)/max(abs(d))))
ax.set_xlabel("PC1 ({:<4.2f}%)".format(vars[0]/sum(vars)*100.0))
ax.set_ylabel("PC2 ({:<4.2f}%)".format(vars[1]/sum(vars)*100.0))

ax = plt.subplot(1,3,2)
kde = KernelDensity().fit(dow_x_pca[:,[0,2]])
d = np.e**(kde.score_samples(dow_x_pca[:,[0,2]]))
ax.scatter(dow_x_pca[:,0],dow_x_pca[:,2],c=cm.viridis(abs(d)/max(abs(d))))
ax.set_xlabel("PC1 ({:<4.2f}%)".format(vars[0]/sum(vars)*100.0))
ax.set_ylabel("PC3 ({:<4.2f}%)".format(vars[2]/sum(vars)*100.0))

ax = plt.subplot(1,3,3)
kde = KernelDensity().fit(dow_x_pca[:,[1,2]])
d = np.e**(kde.score_samples(dow_x_pca[:,[1,2]]))
ax.scatter(dow_x_pca[:,1],dow_x_pca[:,2],c=cm.viridis(abs(d)/max(abs(d))))
ax.set_xlabel("PC2 ({:<4.2f}%)".format(vars[1]/sum(vars)*100.0))
ax.set_ylabel("PC3 ({:<4.2f}%)".format(vars[2]/sum(vars)*100.0))

plt.show()

# %% [markdown]
# In the above cell we have performed the PCA transformation and plotted the data with respect to the first three PCs and reported the %variance along each. We can see from the variances that PC1 alone captures a majority of the variability in the values. In combination, PC1-PC3 capture 75% of the variance. Looking at these numbers, the PC analysis has automatically ascertained what we observed earlier in the correlation analysis: a lot of these variables are correlated and aren't providing much indpendent information. Using only 3 variables we can describe a supermajority of the variance.
#
# Let's look closer at the PC1 vs PC2 plot and color the data according to impurity:

# %%
plt.figure(figsize=(9,8))
plt.scatter(dow_x_pca[:,0],dow_x_pca[:,1],c=dow["y"],cmap="viridis")
plt.xlabel("PC1 ({:<4.2f}%)".format(vars[0]/sum(vars)*100.0))
plt.ylabel("PC2 ({:<4.2f}%)".format(vars[1]/sum(vars)*100.0))
plt.colorbar()
plt.show()

# %% [markdown]
# Looking at this (and the previous) figures, we can see a clear separation between values when the plant is operating with PC1<-1353 and PC2<-106. The vast majority of points resides in a small cluster with relatively few points along the diagonal. We can experiment with using the PC values in this way for identifying outliers:

# %%
# Separate clusters based on PC1 and PC2
i_inds = [ _ for _ in range(len(dow_x_pca)) if dow_x_pca[_,0] < -1353 and dow_x_pca[_,1] < -106 ]
o_inds = [ _ for _ in range(len(dow_x_pca)) if _ not in i_inds ]
print("N outliers: {} ({:<4.2f}%)".format(len(o_inds),len(o_inds)/len(dow_x_pca)*100.0))

# Plot original data with outliers marked
plt.figure(figsize=(12,3))
plt.plot(dow.iloc[o_inds,0],dow.iloc[o_inds,-3],marker='o',color=(0.1,0.8,0.4),linestyle='None')
plt.plot(dow.iloc[i_inds,0],dow.iloc[i_inds,-3],color="k")
plt.xlabel("time")
plt.ylabel("y:Impurity")
plt.title("original with outliers marked")

# Plot original data with outliers replaced by median
plt.figure(figsize=(12,3))
plt.plot(dow.iloc[i_inds,0],dow.iloc[i_inds,-3],marker='.',color="k",linestyle="None")
plt.xlabel("time")
plt.ylabel("y:Impurity")
plt.title("outliers dropped")

# Make scatterplots of first three principle components with outliers marked
plt.figure(figsize=(15,5))
ax = plt.subplot(1,3,1)
ax.scatter(dow_x_pca[i_inds,0],dow_x_pca[i_inds,1],c="k",alpha=0.2)
ax.scatter(dow_x_pca[o_inds,0],dow_x_pca[o_inds,1],c=[(0.1,0.8,0.4)],alpha=0.2)
ax.set_xlabel("PC1 ({:<4.2f}%)".format(vars[0]/sum(vars)*100.0))
ax.set_ylabel("PC2 ({:<4.2f}%)".format(vars[1]/sum(vars)*100.0))

ax = plt.subplot(1,3,2)
ax.scatter(dow_x_pca[i_inds,0],dow_x_pca[i_inds,2],c="k",alpha=0.2)
ax.scatter(dow_x_pca[o_inds,0],dow_x_pca[o_inds,2],c=[(0.1,0.8,0.4)],alpha=0.2)
ax.set_xlabel("PC1 ({:<4.2f}%)".format(vars[0]/sum(vars)*100.0))
ax.set_ylabel("PC3 ({:<4.2f}%)".format(vars[2]/sum(vars)*100.0))

ax = plt.subplot(1,3,3)
ax.scatter(dow_x_pca[i_inds,1],dow_x_pca[i_inds,2],c="k",alpha=0.2)
ax.scatter(dow_x_pca[o_inds,1],dow_x_pca[o_inds,2],c=[(0.1,0.8,0.4)],alpha=0.2)
ax.set_xlabel("PC2 ({:<4.2f}%)".format(vars[1]/sum(vars)*100.0))
ax.set_ylabel("PC3 ({:<4.2f}%)".format(vars[2]/sum(vars)*100.0))

plt.show()
# Out:
# N outliers: 450 (4.37%)

# %% [markdown]
# Impressively, the PCA analysis automatically identified the anomolous region in Feb 2017 where the impurity data became linear.
#
# When we previously investigated the correlation plots, we also saw a separation between the temperature variables that appeared to be "on" vs "off" behavior. Let's see if the PCA analysis also picked up this distinction.

# %%
# Find linearly correlated features 
# There is probably a solution with Pandas .where() that is workable as well. I'm more comfortable with arrays.
corr = dow.corr()
corr_array = corr.abs().to_numpy()[:-5,:-5] # return a numpy array with only absolute values of "xINT:" variables
row,col = np.where((corr_array > 0.95) & (corr_array < 1)) # find positions where correlation mags are >0.95 and !=1
labels = [ (corr.index[row[_]],corr.columns[col[_]]) for _ in range(len(row)) if row[_] > col[_] ] # find labels/cols

### Correlation Grid of features
plt.figure(figsize=(12,12))
inc = -1
for i in range(len(labels)):
  ax = plt.subplot(5,5,i+1)
  ax.scatter(dow.loc[:,labels[i][0]].iloc[i_inds],dow.loc[:,labels[i][1]].iloc[i_inds],c='k',alpha=0.2)
  ax.scatter(dow.loc[:,labels[i][0]].iloc[o_inds],dow.loc[:,labels[i][1]].iloc[o_inds],c=[(0.1,0.8,0.4)],alpha=0.2)
  ax.set_title("R = {:<3.2f}".format(corr.loc[labels[i][0],labels[i][1]]))
  ax.set_xlabel(labels[i][0].split(":")[0])
  ax.set_ylabel(labels[i][1].split(":")[0])
plt.tight_layout()
plt.show()
print("N outliers: {} ({:<4.2f}%)".format(len(o_inds),len(o_inds)/len(dow)*100.0))
# Out:
# N outliers: 450 (4.37%)

# %% [markdown]
# PCA observed the same thing we did, the plant seems to exhibit two states, "on" and "off". Looking at the temperature variables, `x34`, `x18`, and `x19`, we see that the low temperature regions have been identified as outliers (green).
#
# Looking at these plots, it looks like the outliers outnumber the regular operation data. However, only 450 samples (4% of the total) are identified as outliers using our PC1 and PC2 criteria. Thus, the overwhelming majority of the data is bunched in the tiny black clusters shown in the correlation plots. This demonstrates how large of an impact this data has on our analysis, and the need to remove it prior to building a predictive model or providing an analysis of the plant during normal operating conditions.
